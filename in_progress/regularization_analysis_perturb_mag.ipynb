# %%
# Setup and imports
import sys
sys.path.append('../..')

# %load_ext autoreload
# %autoreload 2

import torch
import torch.nn as nn
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from pathlib import Path
import json
import time
from collections import defaultdict
import warnings
warnings.filterwarnings('ignore')

import xfads.utils as utils
import xfads.plot_utils as plot_utils
from xfads.ssm_modules.dynamics import DenseGaussianDynamics
from xfads.ssm_modules.likelihoods import GaussianLikelihood
from xfads.ssm_modules.dynamics import DenseGaussianInitialCondition
from xfads.ssm_modules.encoders import LocalEncoderLRMvn, BackwardEncoderLRMvn
from xfads.smoothers.nonlinear_smoother import NonlinearFilterSmallL

# Our custom modules
from regularized_ssm import RegularizedSSM, create_rotation_vector_field
from loss_analysis_utils import (
    LossComponentAnalyzer, 
    RegularizationStrengthAnalyzer,
    create_perfect_rotation_test
)
from regularizers import LieDerivativeRegularizer

# Set device
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(f"Using device: {device}")

# REPRODUCIBILITY: Set all seeds
SEED = 41
torch.manual_seed(SEED)
np.random.seed(SEED)
if torch.cuda.is_available():
    torch.cuda.manual_seed(SEED)
    torch.cuda.manual_seed_all(SEED)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

print(f"🌱 All seeds set to {SEED} for reproducibility")
# Out:
# Using device: cpu
# 🌱 All seeds set to 41 for reproducibility

# %% [markdown]
# ## 📋 Configuration and Data Generation

# %%
# Enhanced configuration for ring attractor analysis with perturbation magnitude sweep
class Config:
    # Model architecture
    n_latents = 2
    n_latents_read = 2  
    n_hidden_dynamics = 32
    n_hidden_local = 32
    n_hidden_backward = 32
    rank_local = 2
    rank_backward = 2
    p_local_dropout = 0.0
    
    # Training parameters
    n_samples = 5  # Reduced for ring attractor (more complex)
    batch_sz = 32
    learning_rate = 1e-3
    max_epochs = 25  # Reduced for initial analysis
    patience = 5  # Increased patience for ring attractor
    grad_clip = 1.0
    
    # Data parameters (matching demo_regularize.ipynb)
    n_trials = 1000  # Smaller for faster analysis
    n_neurons = 100  # Match demo_regularize.ipynb
    n_time_bins = 75  # Match demo_regularize.ipynb
    train_split = 0.8
    
    # Perturbation magnitude sweep
    perturbation_magnitudes = [0.2, 0.3, 0.4, 0.5]
    
    # Regularization sweep (gradual from very small to moderate)
    lambda_min = 1e-4  # Start smaller for ring attractor
    lambda_max = 1e0   # Don't go too high, ring attractor is more complex
    n_lambda_points = 3  # More points in interesting range
    
    # Reproducibility
    seed = SEED

cfg = Config()

print(f"📋 Ring Attractor Configuration with Perturbation Magnitude Sweep:")
print(f"   Data: {cfg.n_trials} trials × {cfg.n_time_bins} time bins × {cfg.n_neurons} neurons")
print(f"   Model: {cfg.n_latents}D latent space, {cfg.n_hidden_dynamics} hidden dynamics")
print(f"   Training: max {cfg.max_epochs} epochs, lr={cfg.learning_rate}, patience={cfg.patience}")
print(f"   Samples: {cfg.n_samples} (reduced for ring attractor complexity)")
print(f"   Perturbation magnitudes: {cfg.perturbation_magnitudes}")
print(f"   Regularization sweep: {cfg.lambda_min:.1e} to {cfg.lambda_max} ({cfg.n_lambda_points} points)")
print(f"   Focus: Ring attractor data → Rotational symmetry regularization across perturbations")
# Out:
# 📋 Ring Attractor Configuration with Perturbation Magnitude Sweep:
#    Data: 1000 trials × 75 time bins × 100 neurons
#    Model: 2D latent space, 32 hidden dynamics
#    Training: max 25 epochs, lr=0.001, patience=5
#    Samples: 5 (reduced for ring attractor complexity)
#    Perturbation magnitudes: [0.2, 0.3, 0.4, 0.5]
#    Regularization sweep: 1.0e-04 to 1.0 (3 points)
#    Focus: Ring attractor data → Rotational symmetry regularization across perturbations

# %%
# Create ring attractor dynamics and synthetic data (like demo_regularize.ipynb)
import importlib.util

# Load the PerturbedRingAttractorDynamics
file_path = "test_dynamics.py"
module_name = "test_dynamics"

spec = importlib.util.spec_from_file_location(module_name, file_path)
test_dynamics = importlib.util.module_from_spec(spec)
spec.loader.exec_module(test_dynamics)
PerturbedRingAttractorDynamics = test_dynamics.PerturbedRingAttractorRNN

print("🔄 Setting up ring attractor data with perturbation magnitude sweep...")

# Ring attractor parameters - sweep over perturbation magnitudes
perturbation_magnitudes = [0.2, 0.3, 0.4, 0.5]

# Create target field (same for all perturbations)
target_field = create_rotation_vector_field(rotation_speed=0.5)

# Storage for data from each perturbation magnitude
datasets = {}
true_dynamics_dict = {}
perfect_ring_dynamics_dict = {}

print(f"✅ Perturbation magnitude sweep setup:")
print(f"   Magnitudes: {perturbation_magnitudes}")
print(f"   Target field: Rotational symmetry (speed = 0.5)")

# Observation matrix and noise parameters (same for all)
C = utils.FanInLinear(cfg.n_latents, cfg.n_neurons, device=device).requires_grad_(False)
Q_diag = 5e-3 * torch.ones(cfg.n_latents, device=device)  # Process noise
Q_0_diag = 1.0 * torch.ones(cfg.n_latents, device=device)  # Initial condition noise  
R_diag = 1e-1 * torch.ones(cfg.n_neurons, device=device)  # Observation noise
m_0 = torch.zeros(cfg.n_latents, device=device)  # Initial mean

for perturbation_magnitude in perturbation_magnitudes:
    print(f"\n   Generating data for perturbation magnitude {perturbation_magnitude}...")
    
    # Create true ring attractor dynamics (perturbed - used for data generation)
    true_dynamics = PerturbedRingAttractorDynamics(
        bin_sz=1e-1, 
        lengthscale=0.2, 
        perturbation_magnitude=perturbation_magnitude
    ).to(device)
    
    # Create perfect ring attractor dynamics (unperturbed - for comparison)
    perfect_ring_dynamics = PerturbedRingAttractorDynamics(
        bin_sz=1e-1, 
        lengthscale=0.2, 
        perturbation_magnitude=0.0  # No perturbations = perfect ring
    ).to(device)
    
    # Generate ring attractor trajectories and observations using the PERTURBED dynamics
    z_true = utils.sample_gauss_z(true_dynamics, Q_diag, m_0, Q_0_diag, cfg.n_trials, cfg.n_time_bins)
    y = C(z_true) + torch.sqrt(R_diag) * torch.randn((cfg.n_trials, cfg.n_time_bins, cfg.n_neurons), device=device)
    y = y.detach()
    
    # Split into train and validation
    n_train = int(cfg.train_split * cfg.n_trials)
    y_train = y[:n_train]
    y_valid = y[n_train:]
    
    # Store data and dynamics for this perturbation magnitude
    datasets[perturbation_magnitude] = {
        'y_train': y_train,
        'y_valid': y_valid,
        'z_true': z_true,
        'y': y
    }
    true_dynamics_dict[perturbation_magnitude] = true_dynamics
    perfect_ring_dynamics_dict[perturbation_magnitude] = perfect_ring_dynamics
    
    print(f"     Training: {y_train.shape[0]} trials")
    print(f"     Validation: {y_valid.shape[0]} trials")

print(f"\n✅ Ring attractor data generated for all perturbation magnitudes")
print(f"   Each dataset: {cfg.n_trials} trials × {cfg.n_time_bins} time bins × {cfg.n_neurons} neurons")
print(f"\n🎯 For each perturbation magnitude, we compare:")
print(f"   1. Learned dynamics (what we train)")
print(f"   2. Perfect ring attractor (unperturbed)")
print(f"   3. Perturbed ring attractor (data generation)")
# Out:
# 🔄 Setting up ring attractor data with perturbation magnitude sweep...
# ✅ Perturbation magnitude sweep setup:
#    Magnitudes: [0.2, 0.3, 0.4, 0.5]
#    Target field: Rotational symmetry (speed = 0.5)
#
#    Generating data for perturbation magnitude 0.2...
#      Training: 800 trials
#      Validation: 200 trials
#
#    Generating data for perturbation magnitude 0.3...
#      Training: 800 trials
#      Validation: 200 trials
#
#    Generating data for perturbation magnitude 0.4...
#      Training: 800 trials
#      Validation: 200 trials
#
#    Generating data for perturbation magnitude 0.5...
#      Training: 800 trials
#      Validation: 200 trials
#
# ✅ Ring attractor data generated for all perturbation magnitudes
#    Each dataset: 1000 trials × 75 time bins × 100 neurons
#
# 🎯 For each perturbation magnitude, we compare:
#    1. Learned dynamics (what we train)
#    2. Perfect ring attractor (unperturbed)
#    3. Perturbed ring attractor (data generation)

# %%
# Visualize the setup: All three vector fields
fig, axes = plt.subplots(2, 2, figsize=(16, 16))

# 1. True perturbed ring attractor dynamics + trajectories  
ax = axes[0, 0]
plot_utils.plot_two_d_vector_field(true_dynamics.to('cpu'), ax, min_xy=-2, max_xy=2)
for i in range(10):  # Plot subset of trajectories
    ax.plot(z_true[i, :, 0].cpu(), z_true[i, :, 1].cpu(), 'b-', alpha=0.6, linewidth=1)
ax.set_title('Perturbed Ring Attractor\n(Data Generation)', fontweight='bold')
ax.set_xlabel('x₁')
ax.set_ylabel('x₂')
ax.set_xlim(-2, 2)
ax.set_ylim(-2, 2)
ax.set_aspect('equal')
ax.grid(True, alpha=0.3)

# 2. Perfect ring attractor dynamics
ax = axes[0, 1]
plot_utils.plot_two_d_vector_field(perfect_ring_dynamics.to('cpu'), ax, min_xy=-2, max_xy=2)
ax.set_title('Perfect Ring Attractor\n(No Perturbations)', fontweight='bold')
ax.set_xlabel('x₁')
ax.set_ylabel('x₂')
ax.set_xlim(-2, 2)
ax.set_ylim(-2, 2)
ax.set_aspect('equal')
ax.grid(True, alpha=0.3)

# 3. Target rotational field
ax = axes[1, 0]
plot_utils.plot_two_d_vector_field(
    lambda x: x + 1e-2 * target_field(x), ax, min_xy=-2, max_xy=2
)
# plot_utils.plot_two_d_vector_field(
#     target_field, ax, min_xy=-2, max_xy=2
# )
ax.set_title('Target Rotational Field\n(Regularization Goal)', fontweight='bold')
ax.set_xlabel('x₁')
ax.set_ylabel('x₂')
ax.set_xlim(-2, 2)
ax.set_ylim(-2, 2)
ax.set_aspect('equal')
ax.grid(True, alpha=0.3)

# 4. Conceptual illustration
ax = axes[1, 1]
ax.text(0.5, 0.8, 'Training Goal:', ha='center', va='center', fontsize=16, fontweight='bold', transform=ax.transAxes)
ax.text(0.5, 0.65, '• Fit PERTURBED ring data', ha='center', va='center', fontsize=12, transform=ax.transAxes, color='blue')
ax.text(0.5, 0.55, '• Regularized toward ROTATION', ha='center', va='center', fontsize=12, transform=ax.transAxes, color='red')

ax.text(0.5, 0.4, 'Comparisons:', ha='center', va='center', fontsize=16, fontweight='bold', transform=ax.transAxes)
ax.text(0.5, 0.25, '• vs Perfect Ring (structure)', ha='center', va='center', fontsize=12, transform=ax.transAxes, color='green')
ax.text(0.5, 0.15, '• vs Perturbed Ring (data)', ha='center', va='center', fontsize=12, transform=ax.transAxes, color='purple')

ax.text(0.5, 0.05, 'λ controls the trade-off', ha='center', va='center', fontsize=14, fontweight='bold', transform=ax.transAxes)
ax.set_xlim(0, 1)
ax.set_ylim(0, 1)
ax.set_xticks([])
ax.set_yticks([])
ax.set_title('Learning & Comparison\nFramework', fontweight='bold')

# plt.suptitle('Ring Attractor Analysis: Data vs Regularization vs Comparisons', 
            #  fontsize=18, fontweight='bold', y=0.95)
plt.tight_layout()
plt.savefig('ring_attractor_setup_v2.png', dpi=300, bbox_inches='tight')
plt.show()

print("📊 Ring attractor setup visualization saved as 'ring_attractor_setup_v2.png'")
print("🎯 This comprehensive setup allows us to understand:")
print("   - How learning deviates from the data-generating process")  
print("   - How regularization pulls toward rotation symmetry")
print("   - How close we get to the perfect ring structure")
print("   - Trade-offs between data fitting and regularization")
# Out:
# 📊 Ring attractor setup visualization saved as 'ring_attractor_setup_v2.png'
# 🎯 This comprehensive setup allows us to understand:
#    - How learning deviates from the data-generating process
#    - How regularization pulls toward rotation symmetry
#    - How close we get to the perfect ring structure
#    - Trade-offs between data fitting and regularization

# %% [markdown]
# ## 🏗️ Enhanced SSM Factory and Training Functions

# %%
def create_regularized_ssm(lambda_lie=1.0, lambda_curvature=0.0):
    """Factory function to create RegularizedSSM with given parameters."""
    
    # Likelihood
    H = utils.ReadoutLatentMask(cfg.n_latents, cfg.n_latents_read)
    readout_fn = nn.Sequential(H, C)
    likelihood_pdf = GaussianLikelihood(readout_fn, cfg.n_neurons, R_diag, device=device, fix_R=True)

    # Learnable dynamics
    dynamics_fn = utils.build_gru_dynamics_function(cfg.n_latents, cfg.n_hidden_dynamics, device=device)
    dynamics_mod = DenseGaussianDynamics(dynamics_fn, cfg.n_latents, Q_diag, device=device)

    # Initial condition
    initial_condition_pdf = DenseGaussianInitialCondition(cfg.n_latents, m_0, Q_0_diag, device=device)

    # Encoders
    backward_encoder = BackwardEncoderLRMvn(
        cfg.n_latents, cfg.n_hidden_backward, cfg.n_latents,
        rank_local=cfg.rank_local, rank_backward=cfg.rank_backward, device=device
    )
    local_encoder = LocalEncoderLRMvn(
        cfg.n_latents, cfg.n_neurons, cfg.n_hidden_local, cfg.n_latents,
        rank=cfg.rank_local, device=device, dropout=cfg.p_local_dropout
    )

    # Nonlinear filtering
    nl_filter = NonlinearFilterSmallL(dynamics_mod, initial_condition_pdf, device=device)

    # Create regularized SSM
    regularized_ssm = RegularizedSSM(
        dynamics_mod=dynamics_mod,
        likelihood_pdf=likelihood_pdf,
        initial_c_pdf=initial_condition_pdf,
        backward_encoder=backward_encoder,
        local_encoder=local_encoder,
        nl_filter=nl_filter,
        target_vector_field=target_field,
        lambda_lie=lambda_lie,
        lambda_curvature=lambda_curvature,
        lie_normalize="yang",
        device=device
    )
    
    return regularized_ssm

# %%
class ComprehensiveLossLogger:
    """Enhanced logger that tracks loss components and creates comprehensive vector field visualizations."""
    
    def __init__(self, experiment_name=None, save_vector_fields=True, perfect_ring_dynamics=None, 
                 perturbed_ring_dynamics=None, target_field=None):
        self.experiment_name = experiment_name or "unknown_experiment"
        self.save_vector_fields = save_vector_fields
        self.vector_field_save_dir = None
        
        # Store reference dynamics for comparison
        self.perfect_ring_dynamics = perfect_ring_dynamics
        self.perturbed_ring_dynamics = perturbed_ring_dynamics  
        self.target_field = target_field
        
        self.reset()
        
        # Set up vector field saving directory
        if self.save_vector_fields:
            self.vector_field_save_dir = Path(f'vector_field_plots/{self.experiment_name}')
            self.vector_field_save_dir.mkdir(parents=True, exist_ok=True)
            print(f"📁 Vector field plots will be saved to: {self.vector_field_save_dir}")
    
    def reset(self):
        self.train_logs = defaultdict(list)
        self.valid_logs = defaultdict(list)
        self.epochs = []
    
    def compute_vector_field_differences(self, learned_dynamics, grid_size=50):
        """
        Compute differences between learned dynamics and reference fields on a grid.
        
        Returns:
            dict: Contains grid points and difference magnitudes for each comparison
        """
        # Create evaluation grid
        x = np.linspace(-2, 2, grid_size)
        y = np.linspace(-2, 2, grid_size)
        X, Y = np.meshgrid(x, y)
        grid_points = torch.tensor(np.stack([X.flatten(), Y.flatten()], axis=1), dtype=torch.float32)
        
        # Evaluate learned dynamics
        with torch.no_grad():
            learned_output = learned_dynamics(grid_points)
            learned_field = learned_output - grid_points  # Convert to vector field
        
        differences = {}
        
        # Difference from perfect ring attractor
        if self.perfect_ring_dynamics is not None:
            with torch.no_grad():
                perfect_output = self.perfect_ring_dynamics(grid_points)
                perfect_field = perfect_output - grid_points
                diff_perfect = learned_field - perfect_field
                diff_perfect_magnitude = torch.norm(diff_perfect, dim=1)
                differences['perfect_ring'] = {
                    'grid_points': grid_points.numpy(),
                    'grid_shape': (grid_size, grid_size),
                    'difference_magnitude': diff_perfect_magnitude.numpy(),
                    'difference_vector': diff_perfect.numpy(),
                    'max_diff': diff_perfect_magnitude.max().item(),
                    'mean_diff': diff_perfect_magnitude.mean().item()
                }
        
        # Difference from perturbed ring attractor (data generation)
        if self.perturbed_ring_dynamics is not None:
            with torch.no_grad():
                perturbed_output = self.perturbed_ring_dynamics(grid_points)
                perturbed_field = perturbed_output - grid_points
                diff_perturbed = learned_field - perturbed_field
                diff_perturbed_magnitude = torch.norm(diff_perturbed, dim=1)
                differences['perturbed_ring'] = {
                    'grid_points': grid_points.numpy(),
                    'grid_shape': (grid_size, grid_size),
                    'difference_magnitude': diff_perturbed_magnitude.numpy(),
                    'difference_vector': diff_perturbed.numpy(),
                    'max_diff': diff_perturbed_magnitude.max().item(),
                    'mean_diff': diff_perturbed_magnitude.mean().item()
                }
        
        # Difference from target rotational field
        if self.target_field is not None:
            with torch.no_grad():
                target_output = self.target_field(grid_points)
                diff_target = learned_field - target_output
                diff_target_magnitude = torch.norm(diff_target, dim=1)
                differences['target_rotation'] = {
                    'grid_points': grid_points.numpy(),
                    'grid_shape': (grid_size, grid_size),
                    'difference_magnitude': diff_target_magnitude.numpy(),
                    'difference_vector': diff_target.numpy(),
                    'max_diff': diff_target_magnitude.max().item(),
                    'mean_diff': diff_target_magnitude.mean().item()
                }
        
        return differences
    
    def plot_comprehensive_vector_field_analysis(self, ssm, epoch, label=None):
        """
        Create comprehensive vector field analysis including learned field and difference heatmaps.
        """
        if not self.save_vector_fields or self.vector_field_save_dir is None:
            return
        
        # Compute differences
        differences = self.compute_vector_field_differences(ssm.dynamics_mod.mean_fn)
        
        # Determine subplot layout based on available comparisons
        n_comparisons = len(differences)
        if n_comparisons == 0:
            # Just plot learned field
            fig, ax = plt.subplots(figsize=(8, 8))
            axes = [ax]
            titles = ['Learned Vector Field']
        else:
            # Plot learned field + difference heatmaps
            n_cols = min(4, n_comparisons + 1)  # Learned + up to 3 comparisons
            n_rows = (n_comparisons + 1 + n_cols - 1) // n_cols  # Ceiling division
            fig, axes = plt.subplots(n_rows, n_cols, figsize=(6*n_cols, 6*n_rows))
            if n_rows == 1:
                axes = axes if n_cols > 1 else [axes]
            else:
                axes = axes.flatten()
        
        # 1. Plot learned vector field
        ax = axes[0]
        plot_utils.plot_two_d_vector_field(ssm.dynamics_mod.mean_fn, ax, min_xy=-2, max_xy=2)
        ax.set_title('Learned Vector Field', fontsize=14, fontweight='bold')
        ax.set_xlabel('x₁')
        ax.set_ylabel('x₂')
        ax.set_xlim(-2, 2)
        ax.set_ylim(-2, 2)
        ax.set_aspect('equal')
        ax.grid(True, alpha=0.3)
        
        # 2. Plot difference heatmaps
        comparison_names = {
            'perfect_ring': 'Diff from Perfect Ring',
            'perturbed_ring': 'Diff from Perturbed Ring', 
            'target_rotation': 'Diff from Target Rotation'
        }
        
        for i, (key, diff_data) in enumerate(differences.items()):
            if i + 1 >= len(axes):
                break
                
            ax = axes[i + 1]
            
            # Reshape difference magnitude for heatmap
            diff_magnitude = diff_data['difference_magnitude'].reshape(diff_data['grid_shape'])
            X = diff_data['grid_points'][:, 0].reshape(diff_data['grid_shape'])
            Y = diff_data['grid_points'][:, 1].reshape(diff_data['grid_shape'])
            
            # Create heatmap
            im = ax.contourf(X, Y, diff_magnitude, levels=20, cmap='viridis')
            ax.contour(X, Y, diff_magnitude, levels=10, colors='white', alpha=0.3, linewidths=0.5)
            
            # Add colorbar
            cbar = plt.colorbar(im, ax=ax)
            cbar.set_label('Difference Magnitude', rotation=270, labelpad=15)
            
            ax.set_title(f'{comparison_names[key]}\\nMax: {diff_data["max_diff"]:.3f}, Mean: {diff_data["mean_diff"]:.3f}', 
                        fontsize=12, fontweight='bold')
            ax.set_xlabel('x₁')
            ax.set_ylabel('x₂')
            ax.set_xlim(-2, 2)
            ax.set_ylim(-2, 2)
            ax.set_aspect('equal')
            ax.grid(True, alpha=0.3)
        
        # Hide unused subplots
        for i in range(len(differences) + 1, len(axes)):
            axes[i].set_visible(False)
        
        # Set main title
        if label:
            main_title = f'Vector Field Analysis - {label.title()} (Epoch {epoch})'
        else:
            main_title = f'Vector Field Analysis - Epoch {epoch}'
            
        plt.suptitle(main_title, fontsize=16, fontweight='bold')
        plt.tight_layout()
        
        # Save the comprehensive plot
        if label:
            filename = f'vector_field_analysis_epoch_{epoch:03d}_{label}.png'
        else:
            filename = f'vector_field_analysis_epoch_{epoch:03d}.png'
            
        save_path = self.vector_field_save_dir / filename
        fig.savefig(save_path, dpi=300, bbox_inches='tight')
        plt.close(fig)  # Close to save memory
        
        if epoch % 10 == 0 or label:  # Only print occasionally to avoid spam
            print(f"📊 Comprehensive vector field analysis saved: {save_path}")
        
        return differences
    
    def plot_and_save_vector_field(self, ssm, epoch, label=None):
        """
        Plot and save both the basic vector field AND comprehensive analysis.
        """
        if not self.save_vector_fields or self.vector_field_save_dir is None:
            return
        
        # 1. Basic vector field plot (for GIF creation)
        fig, ax = plt.subplots(figsize=(8, 8))
        plot_utils.plot_two_d_vector_field(ssm.dynamics_mod.mean_fn, ax, min_xy=-2, max_xy=2)
        
        if label:
            title = f'Vector Field - {label.title()} (Epoch {epoch})'
        else:
            title = f'Vector Field - Epoch {epoch}'
            
        ax.set_title(title, fontsize=14, fontweight='bold')
        ax.set_xlabel('Latent Dim 1')
        ax.set_ylabel('Latent Dim 2')
        ax.set_xlim(-2, 2)
        ax.set_ylim(-2, 2)
        ax.set_aspect('equal')
        ax.grid(True, alpha=0.3)
        
        if label:
            filename = f'vector_field_epoch_{epoch:03d}_{label}.png'
        else:
            filename = f'vector_field_epoch_{epoch:03d}.png'
            
        save_path = self.vector_field_save_dir / filename
        fig.savefig(save_path, dpi=300, bbox_inches='tight')
        plt.close(fig)
        
        # 2. Comprehensive analysis with heatmaps
        differences = self.plot_comprehensive_vector_field_analysis(ssm, epoch, label)
        
        return differences
    
    def create_before_after_comparison(self, ssm):
        """
        Create comprehensive before/after comparison with all reference fields.
        """
        if not self.save_vector_fields or self.vector_field_save_dir is None:
            return
            
        fig, axes = plt.subplots(2, 3, figsize=(18, 12))
        
        # Top row: Reference fields
        if self.perfect_ring_dynamics is not None:
            plot_utils.plot_two_d_vector_field(self.perfect_ring_dynamics, axes[0, 0], min_xy=-2, max_xy=2)
            axes[0, 0].set_title('Perfect Ring Attractor', fontsize=12, fontweight='bold')
        else:
            axes[0, 0].text(0.5, 0.5, 'Perfect Ring\nNot Available', ha='center', va='center', transform=axes[0, 0].transAxes)
            axes[0, 0].set_title('Perfect Ring Attractor', fontsize=12, fontweight='bold')
        
        if self.perturbed_ring_dynamics is not None:
            plot_utils.plot_two_d_vector_field(self.perturbed_ring_dynamics, axes[0, 1], min_xy=-2, max_xy=2)
            axes[0, 1].set_title('Perturbed Ring (Data)', fontsize=12, fontweight='bold')
        else:
            axes[0, 1].text(0.5, 0.5, 'Perturbed Ring\nNot Available', ha='center', va='center', transform=axes[0, 1].transAxes)
            axes[0, 1].set_title('Perturbed Ring (Data)', fontsize=12, fontweight='bold')
        
        if self.target_field is not None:
            plot_utils.plot_two_d_vector_field(self.target_field, axes[0, 2], min_xy=-2, max_xy=2)
            axes[0, 2].set_title('Target Rotation', fontsize=12, fontweight='bold')
        else:
            axes[0, 2].text(0.5, 0.5, 'Target Field\nNot Available', ha='center', va='center', transform=axes[0, 2].transAxes)
            axes[0, 2].set_title('Target Rotation', fontsize=12, fontweight='bold')
        
        # Bottom row: Learned field and key differences
        plot_utils.plot_two_d_vector_field(ssm.dynamics_mod.mean_fn, axes[1, 0], min_xy=-2, max_xy=2)
        axes[1, 0].set_title('Final Learned Field', fontsize=12, fontweight='bold')
        
        # Compute final differences for summary
        differences = self.compute_vector_field_differences(ssm.dynamics_mod.mean_fn, grid_size=30)
        
        # Show most relevant difference heatmaps
        if 'perturbed_ring' in differences:
            diff_data = differences['perturbed_ring']
            diff_magnitude = diff_data['difference_magnitude'].reshape(diff_data['grid_shape'])
            X = diff_data['grid_points'][:, 0].reshape(diff_data['grid_shape'])
            Y = diff_data['grid_points'][:, 1].reshape(diff_data['grid_shape'])
            
            im = axes[1, 1].contourf(X, Y, diff_magnitude, levels=15, cmap='viridis')
            axes[1, 1].set_title(f'Diff from Data Gen\\n(Mean: {diff_data["mean_diff"]:.3f})', fontsize=12, fontweight='bold')
            plt.colorbar(im, ax=axes[1, 1])
        
        if 'target_rotation' in differences:
            diff_data = differences['target_rotation']
            diff_magnitude = diff_data['difference_magnitude'].reshape(diff_data['grid_shape'])
            X = diff_data['grid_points'][:, 0].reshape(diff_data['grid_shape'])
            Y = diff_data['grid_points'][:, 1].reshape(diff_data['grid_shape'])
            
            im = axes[1, 2].contourf(X, Y, diff_magnitude, levels=15, cmap='plasma')
            axes[1, 2].set_title(f'Diff from Target\\n(Mean: {diff_data["mean_diff"]:.3f})', fontsize=12, fontweight='bold')
            plt.colorbar(im, ax=axes[1, 2])
        
        # Format all axes
        for ax in axes.flat:
            ax.set_xlim(-2, 2)
            ax.set_ylim(-2, 2)
            ax.set_aspect('equal')
            ax.grid(True, alpha=0.3)
            ax.set_xlabel('x₁')
            ax.set_ylabel('x₂')
        
        plt.suptitle(f'Comprehensive Vector Field Comparison (λ={ssm.lambda_lie:.2e})', 
                    fontsize=16, fontweight='bold')
        plt.tight_layout()
        
        # Save comparison
        comparison_path = self.vector_field_save_dir / 'comprehensive_comparison.png'
        fig.savefig(comparison_path, dpi=300, bbox_inches='tight')
        plt.close(fig)
        
        print(f"📊 Comprehensive comparison plot saved: {comparison_path}")
        
    def log_epoch(self, epoch, train_stats, valid_stats):
        """Log key loss components for both training and validation."""
        self.epochs.append(epoch)
        
        # Define which losses to track
        loss_keys = ['total_loss', 'elbo_loss', 'lie_loss', 'recon_loss', 'kl_loss', 'total_reg_loss']
        
        # Log training losses
        for key in loss_keys:
            if key in train_stats:
                value = train_stats[key]
                if isinstance(value, torch.Tensor):
                    self.train_logs[key].append(value.item())
                else:
                    self.train_logs[key].append(value)
        
        # Log validation losses
        for key in loss_keys:
            if key in valid_stats:
                value = valid_stats[key]
                if isinstance(value, torch.Tensor):
                    self.valid_logs[key].append(value.item())
                else:
                    self.valid_logs[key].append(value)
    
    def get_dataframe(self):
        """Convert logs to pandas DataFrame for analysis."""
        data = {'epoch': self.epochs}
        
        # Add training data with 'train_' prefix
        for key, values in self.train_logs.items():
            data[f'train_{key}'] = values
            
        # Add validation data with 'valid_' prefix
        for key, values in self.valid_logs.items():
            data[f'valid_{key}'] = values
            
        return pd.DataFrame(data)
    
    def plot_training_curves(self, save_path=None):
        """Plot training curves for the tracked losses."""
        df = self.get_dataframe()
        
        fig, axes = plt.subplots(2, 3, figsize=(18, 12))
        axes = axes.flatten()
        
        # Define what to plot
        loss_types = ['total_loss', 'elbo_loss', 'lie_loss', 'recon_loss', 'kl_loss', 'total_reg_loss']
        
        for i, loss_type in enumerate(loss_types):
            ax = axes[i]
            
            train_col = f'train_{loss_type}'
            valid_col = f'valid_{loss_type}'
            
            if train_col in df.columns:
                ax.semilogy(df['epoch'], df[train_col], 'b-', label='Train', linewidth=2)
            if valid_col in df.columns:
                ax.semilogy(df['epoch'], df[valid_col], 'r-', label='Valid', linewidth=2)
                
            ax.set_title(loss_type.replace('_', ' ').title(), fontweight='bold')
            ax.set_xlabel('Epoch')
            ax.set_ylabel('Loss')
            ax.legend()
            ax.grid(True, alpha=0.3)
        
        plt.tight_layout()
        if save_path:
            plt.savefig(save_path, dpi=300, bbox_inches='tight')
        
        return fig

# %%
def train_with_comprehensive_logging(ssm, y_train, y_valid, logger, lambda_lie=1.0):
    """Enhanced training function with comprehensive loss logging, early stopping, and vector field plotting."""
    
    optimizer = torch.optim.Adam(ssm.parameters(), lr=cfg.learning_rate)
    
    # Early stopping based on validation ELBO
    best_valid_elbo = float('inf')
    patience_counter = 0
    best_model_state = None
    
    print(f"🚀 Training with λ_lie = {lambda_lie:.2e}")
    print(f"   Max epochs: {cfg.max_epochs}, Patience: {cfg.patience}")
    print(f"   Early stopping on: validation ELBO loss")
    
    # Plot and save initial vector field (before training)
    logger.plot_and_save_vector_field(ssm, epoch=-1, label="initial")
    
    # Get initial losses before any training (epoch 0)
    ssm.eval()
    with torch.no_grad():
        # Initial training loss (small batch to match training)
        train_batch = y_train[:cfg.batch_sz]
        initial_train_loss, _, initial_train_stats = ssm(train_batch, cfg.n_samples)
        
        # Initial validation loss
        initial_valid_loss, _, initial_valid_stats = ssm(y_valid, cfg.n_samples)
    
    # Log initial state
    logger.log_epoch(0, initial_train_stats, initial_valid_stats)
    print(f"   Initial: Train ELBO = {initial_train_stats['elbo_loss']:.3f}, "
          f"Valid ELBO = {initial_valid_stats['elbo_loss']:.3f}, "
          f"Lie = {initial_valid_stats['lie_loss']:.3f}")
    
    for epoch in range(1, cfg.max_epochs + 1):
        # Training phase
        ssm.train()
        train_losses = []
        
        # Shuffle training data
        indices = torch.randperm(len(y_train))
        
        for i in range(0, len(y_train), cfg.batch_sz):
            batch_indices = indices[i:i+cfg.batch_sz]
            y_batch = y_train[batch_indices]
            
            optimizer.zero_grad()
            total_loss, _, stats = ssm(y_batch, cfg.n_samples)
            total_loss.backward()
            
            # Gradient clipping
            torch.nn.utils.clip_grad_norm_(ssm.parameters(), cfg.grad_clip)
            optimizer.step()
            
            train_losses.append(stats)
        
        # Average training statistics
        train_stats = {}
        for key in train_losses[0].keys():
            train_stats[key] = torch.stack([batch[key] for batch in train_losses]).mean()
        
        # Validation phase
        ssm.eval()
        with torch.no_grad():
            valid_total_loss, _, valid_stats = ssm(y_valid, cfg.n_samples)
        
        # Log epoch
        logger.log_epoch(epoch, train_stats, valid_stats)
        
        # Plot and save vector field after this epoch
        logger.plot_and_save_vector_field(ssm, epoch)
        
        # Early stopping check (using validation ELBO)
        current_valid_elbo = valid_stats['elbo_loss'].item()
        
        if current_valid_elbo < best_valid_elbo:
            best_valid_elbo = current_valid_elbo
            patience_counter = 0
            best_model_state = ssm.state_dict().copy()
        else:
            patience_counter += 1
        
        # Print progress every 10 epochs
        if epoch % 10 == 0 or patience_counter == 0:
            print(f"   Epoch {epoch:3d}: Train ELBO = {train_stats['elbo_loss']:.3f}, "
                  f"Valid ELBO = {current_valid_elbo:.3f}, "
                  f"Lie = {valid_stats['lie_loss']:.3f}, "
                  f"Patience = {patience_counter}/{cfg.patience}")
        
        # Early stopping
        # if patience_counter >= cfg.patience:
        #     print(f"   🛑 Early stopping at epoch {epoch} (best valid ELBO: {best_valid_elbo:.6f})")
        #     break
    
    # Restore best model
    if best_model_state is not None:
        ssm.load_state_dict(best_model_state)
        print(f"   ✅ Restored model with best validation ELBO: {best_valid_elbo:.6f}")
    
    # Plot and save final vector field
    logger.plot_and_save_vector_field(ssm, epoch, label="final")
    
    # Create target vs final comparison
    logger.create_before_after_comparison(ssm)
    
    print(f"🎯 All vector field plots saved to: {logger.vector_field_save_dir}")
    
    return {
        'final_epoch': epoch,
        'best_valid_elbo': best_valid_elbo,
        'converged': patience_counter < cfg.patience
    }

# %% [markdown]
# ## 🔍 Gradual Regularization Strength Analysis

# %%
# Define gradual lambda sweep (much more fine-grained), including 0
lambda_values = np.concatenate(([0.0], np.logspace(np.log10(cfg.lambda_min), np.log10(cfg.lambda_max), cfg.n_lambda_points)))

print(f"🔬 Gradual regularization analysis:")
print(f"   Range: 0.0 to {cfg.lambda_max}")
print(f"   Points: {len(lambda_values)} (logarithmically spaced, plus 0)")
print(f"   First few values: {[f'{x:.2e}' for x in lambda_values[:5]]}")
print(f"   Last few values: {[f'{x:.2e}' for x in lambda_values[-5:]]}")

# Storage for results
all_results = []
all_loggers = {}
trained_models = {}

print(f"\n🚀 Starting training sweep...")
start_time = time.time()
# Out:
# 🔬 Gradual regularization analysis:
#    Range: 0.0 to 1.0
#    Points: 4 (logarithmically spaced, plus 0)
#    First few values: ['0.00e+00', '1.00e-04', '1.00e-02', '1.00e+00']
#    Last few values: ['0.00e+00', '1.00e-04', '1.00e-02', '1.00e+00']
#
# 🚀 Starting training sweep...

# %%
# Run training sweep across both perturbation magnitudes and lambda values
all_results = []
all_loggers = {}
trained_models = {}

# Define lambda sweep
lambda_values = np.concatenate(([0.0], np.logspace(np.log10(cfg.lambda_min), np.log10(cfg.lambda_max), cfg.n_lambda_points)))

print(f"🔬 Comprehensive analysis: Perturbation magnitude × Regularization strength:")
print(f"   Perturbation magnitudes: {cfg.perturbation_magnitudes}")
print(f"   Lambda values: {len(lambda_values)} points from 0.0 to {cfg.lambda_max}")
print(f"   Total experiments: {len(cfg.perturbation_magnitudes)} × {len(lambda_values)} = {len(cfg.perturbation_magnitudes) * len(lambda_values)}")

print(f"\n🚀 Starting comprehensive training sweep...")
start_time = time.time()

for perturb_idx, perturbation_magnitude in enumerate(cfg.perturbation_magnitudes):
    print(f"\n{'='*80}")
    print(f"🎯 PERTURBATION MAGNITUDE {perturbation_magnitude} ({perturb_idx+1}/{len(cfg.perturbation_magnitudes)})")
    print(f"{'='*80}")
    
    # Get data for this perturbation magnitude
    y_train = datasets[perturbation_magnitude]['y_train']
    y_valid = datasets[perturbation_magnitude]['y_valid']
    true_dynamics = true_dynamics_dict[perturbation_magnitude]
    perfect_ring_dynamics = perfect_ring_dynamics_dict[perturbation_magnitude]
    
    for lambda_idx, lambda_lie in enumerate(lambda_values):
        print(f"\n--- Training {lambda_idx+1}/{len(lambda_values)}: λ = {lambda_lie:.2e}, perturbation = {perturbation_magnitude} ---")
        
        # Reset seed before each model creation for identical initialization
        torch.manual_seed(cfg.seed)
        np.random.seed(cfg.seed)
        if torch.cuda.is_available():
            torch.cuda.manual_seed(cfg.seed)
        
        # Create fresh model
        ssm = create_regularized_ssm(lambda_lie=lambda_lie)
        
        # Create enhanced logger with reference dynamics for comparison
        experiment_name = f"perturb_{perturbation_magnitude}_lambda_{lambda_lie:.2e}".replace(".", "_").replace("+", "").replace("-", "neg")
        logger = ComprehensiveLossLogger(
            experiment_name=experiment_name, 
            save_vector_fields=True,
            perfect_ring_dynamics=perfect_ring_dynamics,  # Perfect ring (no perturbations)
            perturbed_ring_dynamics=true_dynamics,        # Perturbed ring (data generation)
            target_field=target_field                     # Rotational target field
        )
        
        # Train with comprehensive logging and vector field analysis
        training_result = train_with_comprehensive_logging(
            ssm, y_train, y_valid, logger, lambda_lie=lambda_lie
        )
        
        # Get final validation statistics
        ssm.eval()
        with torch.no_grad():
            final_total_loss, _, final_stats = ssm(y_valid, cfg.n_samples)
        
        # Store results with comprehensive information
        result = {
            'perturbation_magnitude': perturbation_magnitude,
            'lambda_lie': lambda_lie,
            'final_epoch': training_result['final_epoch'],
            'best_valid_elbo': training_result['best_valid_elbo'],
            'converged': training_result['converged'],
            'final_total_loss': final_total_loss.item(),
            'final_elbo_loss': final_stats['elbo_loss'].item(),
            'final_lie_loss': final_stats['lie_loss'].item(),
            'final_total_reg_loss': final_stats['total_reg_loss'].item(),
            'experiment_name': experiment_name,
            'vector_field_dir': str(logger.vector_field_save_dir)
        }
        
        # Add optional keys if they exist
        if 'recon_loss' in final_stats:
            result['final_recon_loss'] = final_stats['recon_loss'].item()
        if 'kl_loss' in final_stats:
            result['final_kl_loss'] = final_stats['kl_loss'].item()
        
        # Compute final vector field differences for quantitative analysis
        final_differences = logger.compute_vector_field_differences(ssm.dynamics_mod.mean_fn)
        for ref_name, diff_data in final_differences.items():
            result[f'final_diff_{ref_name}_mean'] = diff_data['mean_diff']
            result[f'final_diff_{ref_name}_max'] = diff_data['max_diff']
        
        all_results.append(result)
        experiment_key = (perturbation_magnitude, lambda_lie)
        all_loggers[experiment_key] = logger
        trained_models[experiment_key] = ssm.state_dict().copy()
        
        print(f"   Final: ELBO = {result['final_elbo_loss']:.3f}, "
              f"Lie = {result['final_lie_loss']:.3f}, "
              f"Total = {result['final_total_loss']:.3f}")
        
        # Print difference summary
        for ref_name, diff_data in final_differences.items():
            print(f"   📊 Diff from {ref_name}: mean={diff_data['mean_diff']:.3f}, max={diff_data['max_diff']:.3f}")

elapsed_time = time.time() - start_time
print(f"\n✅ Comprehensive sweep completed in {elapsed_time/60:.1f} minutes")
print(f"   Trained {len(all_results)} models successfully")
print(f"   📊 Vector field evolution + difference heatmaps saved for each experiment")
print(f"   📁 All comprehensive analyses organized in: vector_field_plots/")
print(f"\n🎬 Each experiment includes analysis across perturbation magnitudes and regularization strengths")
print(f"   This allows studying how both data complexity and regularization affect learning")
# Out:
# 🔬 Comprehensive analysis: Perturbation magnitude × Regularization strength:
#    Perturbation magnitudes: [0.2, 0.3, 0.4, 0.5]
#    Lambda values: 4 points from 0.0 to 1.0
#    Total experiments: 4 × 4 = 16
#
# 🚀 Starting comprehensive training sweep...
#
# ================================================================================
# 🎯 PERTURBATION MAGNITUDE 0.2 (1/4)
# ================================================================================
#
# --- Training 1/4: λ = 0.00e+00, perturbation = 0.2 ---
# 📁 Vector field plots will be saved to: vector_field_plots/perturb_0_2_lambda_0_00e00
# 🚀 Training with λ_lie = 0.00e+00
#    Max epochs: 25, Patience: 5
#    Early stopping on: validation ELBO loss
# 📊 Comprehensive vector field analysis saved: vector_field_plots/perturb_0_2_lambda_0_00e00/vector_field_analysis_epoch_-01_initial.png
#    Initial: Train ELBO = 22780.502, Valid ELBO = 21843.164, Lie = 0.000
#    Epoch   1: Train ELBO = 21483.631, Valid ELBO = 20937.527, Lie = 0.000, Patience = 0/5
#    Epoch   2: Train ELBO = 20437.598, Valid ELBO = 19775.830, Lie = 0.000, Patience = 0/5
#    Epoch   3: Train ELBO = 15456.485, Valid ELBO = 12548.030, Lie = 0.000, Patience = 0/5
#    Epoch   4: Train ELBO = 10867.763, Valid ELBO = 10969.139, Lie = 0.000, Patience = 0/5
#    Epoch   5: Train ELBO = 9947.351, Valid ELBO = 10320.505, Lie = 0.000, Patience = 0/5
#    Epoch   6: Train ELBO = 8213.887, Valid ELBO = 5432.399, Lie = 0.000, Patience = 0/5
#    Epoch   7: Train ELBO = 3707.464, Valid ELBO = 2982.810, Lie = 0.000, Patience = 0/5
#    Epoch   8: Train ELBO = 2855.009, Valid ELBO = 2724.368, Lie = 0.000, Patience = 0/5
#    Epoch   9: Train ELBO = 2699.989, Valid ELBO = 2649.063, Lie = 0.000, Patience = 0/5
# 📊 Comprehensive vector field analysis saved: vector_field_plots/perturb_0_2_lambda_0_00e00/vector_field_analysis_epoch_010.png
#    Epoch  10: Train ELBO = 2625.203, Valid ELBO = 2583.016, Lie = 0.000, Patience = 0/5
#    Epoch  11: Train ELBO = 2579.140, Valid ELBO = 2561.477, Lie = 0.000, Patience = 0/5
#    Epoch  12: Train ELBO = 2529.908, Valid ELBO = 2507.782, Lie = 0.000, Patience = 0/5
#    Epoch  13: Train ELBO = 2495.870, Valid ELBO = 2481.604, Lie = 0.000, Patience = 0/5
#    Epoch  14: Train ELBO = 2467.120, Valid ELBO = 2459.055, Lie = 0.000, Patience = 0/5
#    Epoch  15: Train ELBO = 2442.579, Valid ELBO = 2427.736, Lie = 0.000, Patience = 0/5
#    Epoch  16: Train ELBO = 2422.443, Valid ELBO = 2410.520, Lie = 0.000, Patience = 0/5
#    Epoch  17: Train ELBO = 2406.703, Valid ELBO = 2387.778, Lie = 0.000, Patience = 0/5
#    Epoch  18: Train ELBO = 2388.281, Valid ELBO = 2381.319, Lie = 0.000, Patience = 0/5
#    Epoch  19: Train ELBO = 2381.008, Valid ELBO = 2361.336, Lie = 0.000, Patience = 0/5
# 📊 Comprehensive vector field analysis saved: vector_field_plots/perturb_0_2_lambda_0_00e00/vector_field_analysis_epoch_020.png
#    Epoch  20: Train ELBO = 2368.981, Valid ELBO = 2357.272, Lie = 0.000, Patience = 0/5
#    Epoch  21: Train ELBO = 2358.219, Valid ELBO = 2346.719, Lie = 0.000, Patience = 0/5
#    Epoch  22: Train ELBO = 2350.831, Valid ELBO = 2344.788, Lie = 0.000, Patience = 0/5
#    Epoch  23: Train ELBO = 2342.139, Valid ELBO = 2338.287, Lie = 0.000, Patience = 0/5
#    Epoch  24: Train ELBO = 2335.295, Valid ELBO = 2327.296, Lie = 0.000, Patience = 0/5
#    Epoch  25: Train ELBO = 2329.598, Valid ELBO = 2319.933, Lie = 0.000, Patience = 0/5
#    ✅ Restored model with best validation ELBO: 2319.932861
# 📊 Comprehensive vector field analysis saved: vector_field_plots/perturb_0_2_lambda_0_00e00/vector_field_analysis_epoch_025_final.png
# 📊 Comprehensive comparison plot saved: vector_field_plots/perturb_0_2_lambda_0_00e00/comprehensive_comparison.png
# 🎯 All vector field plots saved to: vector_field_plots/perturb_0_2_lambda_0_00e00
#    Final: ELBO = 2318.312, Lie = 0.000, Total = 2318.312
#    📊 Diff from perfect_ring: mean=0.109, max=0.454
#    📊 Diff from perturbed_ring: mean=0.108, max=0.462
#    📊 Diff from target_rotation: mean=0.833, max=1.814
#
# --- Training 2/4: λ = 1.00e-04, perturbation = 0.2 ---
# 📁 Vector field plots will be saved to: vector_field_plots/perturb_0_2_lambda_1_00eneg04
# 🚀 Training with λ_lie = 1.00e-04
#    Max epochs: 25, Patience: 5
#    Early stopping on: validation ELBO loss
# 📊 Comprehensive vector field analysis saved: vector_field_plots/perturb_0_2_lambda_1_00eneg04/vector_field_analysis_epoch_-01_initial.png
#    Initial: Train ELBO = 22782.340, Valid ELBO = 21848.057, Lie = 9138620.000
#    Epoch   1: Train ELBO = 21502.312, Valid ELBO = 20908.936, Lie = 665760.438, Patience = 0/5
#    Epoch   2: Train ELBO = 20403.707, Valid ELBO = 19463.938, Lie = 506294.312, Patience = 0/5
#    Epoch   3: Train ELBO = 15196.112, Valid ELBO = 11798.562, Lie = 934965.062, Patience = 0/5
#    Epoch   4: Train ELBO = 11088.447, Valid ELBO = 10937.513, Lie = 834872.375, Patience = 0/5
#    Epoch   5: Train ELBO = 10205.037, Valid ELBO = 10695.140, Lie = 197749.547, Patience = 0/5
#    Epoch   6: Train ELBO = 9488.409, Valid ELBO = 9680.628, Lie = 77483.859, Patience = 0/5
#    Epoch   7: Train ELBO = 7731.980, Valid ELBO = 6037.876, Lie = 8347.702, Patience = 0/5
#    Epoch   8: Train ELBO = 3902.386, Valid ELBO = 2864.127, Lie = 204.359, Patience = 0/5
#    Epoch   9: Train ELBO = 2772.782, Valid ELBO = 2678.953, Lie = 139.074, Patience = 0/5
# 📊 Comprehensive vector field analysis saved: vector_field_plots/perturb_0_2_lambda_1_00eneg04/vector_field_analysis_epoch_010.png
#    Epoch  10: Train ELBO = 2646.210, Valid ELBO = 2588.938, Lie = 112.664, Patience = 0/5
#    Epoch  11: Train ELBO = 2582.283, Valid ELBO = 2546.406, Lie = 77.084, Patience = 0/5
#    Epoch  12: Train ELBO = 2522.715, Valid ELBO = 2499.204, Lie = 67.487, Patience = 0/5
#    Epoch  13: Train ELBO = 2487.973, Valid ELBO = 2464.894, Lie = 62.299, Patience = 0/5
#    Epoch  14: Train ELBO = 2458.185, Valid ELBO = 2440.610, Lie = 38.078, Patience = 0/5
#    Epoch  15: Train ELBO = 2432.636, Valid ELBO = 2423.220, Lie = 37.587, Patience = 0/5
#    Epoch  16: Train ELBO = 2413.717, Valid ELBO = 2404.697, Lie = 33.641, Patience = 0/5
#    Epoch  17: Train ELBO = 2399.839, Valid ELBO = 2382.393, Lie = 43.380, Patience = 0/5
#    Epoch  18: Train ELBO = 2385.340, Valid ELBO = 2380.379, Lie = 30.426, Patience = 0/5
#    Epoch  19: Train ELBO = 2383.623, Valid ELBO = 2361.112, Lie = 29.915, Patience = 0/5
# 📊 Comprehensive vector field analysis saved: vector_field_plots/perturb_0_2_lambda_1_00eneg04/vector_field_analysis_epoch_020.png
#    Epoch  20: Train ELBO = 2369.480, Valid ELBO = 2364.433, Lie = 32.171, Patience = 1/5
#    Epoch  21: Train ELBO = 2359.618, Valid ELBO = 2350.430, Lie = 29.039, Patience = 0/5
#    Epoch  22: Train ELBO = 2352.751, Valid ELBO = 2342.596, Lie = 26.005, Patience = 0/5
#    Epoch  23: Train ELBO = 2342.351, Valid ELBO = 2336.050, Lie = 35.801, Patience = 0/5
#    Epoch  24: Train ELBO = 2335.841, Valid ELBO = 2327.166, Lie = 30.930, Patience = 0/5
#    Epoch  25: Train ELBO = 2332.564, Valid ELBO = 2323.697, Lie = 33.763, Patience = 0/5
#    ✅ Restored model with best validation ELBO: 2323.696533
# 📊 Comprehensive vector field analysis saved: vector_field_plots/perturb_0_2_lambda_1_00eneg04/vector_field_analysis_epoch_025_final.png
# 📊 Comprehensive comparison plot saved: vector_field_plots/perturb_0_2_lambda_1_00eneg04/comprehensive_comparison.png
# 🎯 All vector field plots saved to: vector_field_plots/perturb_0_2_lambda_1_00eneg04
#    Final: ELBO = 2321.796, Lie = 33.617, Total = 2321.800
#    📊 Diff from perfect_ring: mean=0.111, max=0.453
#    📊 Diff from perturbed_ring: mean=0.110, max=0.462
#    📊 Diff from target_rotation: mean=0.836, max=1.823
#
# --- Training 3/4: λ = 1.00e-02, perturbation = 0.2 ---
# 📁 Vector field plots will be saved to: vector_field_plots/perturb_0_2_lambda_1_00eneg02
# 🚀 Training with λ_lie = 1.00e-02
#    Max epochs: 25, Patience: 5
#    Early stopping on: validation ELBO loss
# 📊 Comprehensive vector field analysis saved: vector_field_plots/perturb_0_2_lambda_1_00eneg02/vector_field_analysis_epoch_-01_initial.png
#    Initial: Train ELBO = 22785.254, Valid ELBO = 21853.357, Lie = 9151892.000
#    Epoch   1: Train ELBO = 21736.283, Valid ELBO = 20589.861, Lie = 222335.562, Patience = 0/5
#    Epoch   2: Train ELBO = 20031.324, Valid ELBO = 16793.832, Lie = 131483.469, Patience = 0/5
#    Epoch   3: Train ELBO = 14531.423, Valid ELBO = 12298.595, Lie = 249752.000, Patience = 0/5
#    Epoch   4: Train ELBO = 12560.638, Valid ELBO = 11291.790, Lie = 162146.375, Patience = 0/5
#    Epoch   5: Train ELBO = 11310.643, Valid ELBO = 10864.693, Lie = 95636.750, Patience = 0/5
#    Epoch   6: Train ELBO = 10677.305, Valid ELBO = 10835.889, Lie = 83715.781, Patience = 0/5
#    Epoch   8: Train ELBO = 10021.080, Valid ELBO = 10535.980, Lie = 114049.359, Patience = 0/5
#    Epoch   9: Train ELBO = 9764.744, Valid ELBO = 10264.989, Lie = 126799.906, Patience = 0/5
# 📊 Comprehensive vector field analysis saved: vector_field_plots/perturb_0_2_lambda_1_00eneg02/vector_field_analysis_epoch_010.png
#    Epoch  10: Train ELBO = 9653.289, Valid ELBO = 10060.950, Lie = 140406.422, Patience = 0/5
#    Epoch  12: Train ELBO = 8900.181, Valid ELBO = 9267.244, Lie = 176811.750, Patience = 0/5
#    Epoch  13: Train ELBO = 8406.003, Valid ELBO = 8949.592, Lie = 316971.594, Patience = 0/5
#    Epoch  14: Train ELBO = 8475.847, Valid ELBO = 8822.301, Lie = 231561.719, Patience = 0/5
#    Epoch  15: Train ELBO = 8078.148, Valid ELBO = 8127.334, Lie = 65602.930, Patience = 0/5
#    Epoch  16: Train ELBO = 6328.617, Valid ELBO = 4837.501, Lie = 12107.152, Patience = 0/5
#    Epoch  17: Train ELBO = 3499.683, Valid ELBO = 2706.817, Lie = 951.447, Patience = 0/5
#    Epoch  18: Train ELBO = 2631.183, Valid ELBO = 2530.752, Lie = 242.961, Patience = 0/5
#    Epoch  19: Train ELBO = 2513.025, Valid ELBO = 2456.089, Lie = 163.396, Patience = 0/5
# 📊 Comprehensive vector field analysis saved: vector_field_plots/perturb_0_2_lambda_1_00eneg02/vector_field_analysis_epoch_020.png
#    Epoch  20: Train ELBO = 2461.893, Valid ELBO = 2433.700, Lie = 153.562, Patience = 0/5
#    Epoch  21: Train ELBO = 2425.080, Valid ELBO = 2403.531, Lie = 102.859, Patience = 0/5
#    Epoch  22: Train ELBO = 2403.436, Valid ELBO = 2389.806, Lie = 82.141, Patience = 0/5
#    Epoch  23: Train ELBO = 2390.742, Valid ELBO = 2378.490, Lie = 59.670, Patience = 0/5
#    Epoch  24: Train ELBO = 2374.290, Valid ELBO = 2366.569, Lie = 51.292, Patience = 0/5
#    Epoch  25: Train ELBO = 2365.601, Valid ELBO = 2354.089, Lie = 50.921, Patience = 0/5
#    ✅ Restored model with best validation ELBO: 2354.089111
# 📊 Comprehensive vector field analysis saved: vector_field_plots/perturb_0_2_lambda_1_00eneg02/vector_field_analysis_epoch_025_final.png
# 📊 Comprehensive comparison plot saved: vector_field_plots/perturb_0_2_lambda_1_00eneg02/comprehensive_comparison.png
# 🎯 All vector field plots saved to: vector_field_plots/perturb_0_2_lambda_1_00eneg02
#    Final: ELBO = 2349.656, Lie = 43.756, Total = 2350.094
#    📊 Diff from perfect_ring: mean=0.114, max=0.521
#    📊 Diff from perturbed_ring: mean=0.115, max=0.532
#    📊 Diff from target_rotation: mean=0.852, max=1.920
#
# --- Training 4/4: λ = 1.00e+00, perturbation = 0.2 ---
# 📁 Vector field plots will be saved to: vector_field_plots/perturb_0_2_lambda_1_00e00
# 🚀 Training with λ_lie = 1.00e+00
#    Max epochs: 25, Patience: 5
#    Early stopping on: validation ELBO loss
# 📊 Comprehensive vector field analysis saved: vector_field_plots/perturb_0_2_lambda_1_00e00/vector_field_analysis_epoch_-01_initial.png
#    Initial: Train ELBO = 22785.271, Valid ELBO = 21852.980, Lie = 9149534.000
#    Epoch   1: Train ELBO = 22930.676, Valid ELBO = 23012.395, Lie = 65242.199, Patience = 0/5
#    Epoch   2: Train ELBO = 22822.510, Valid ELBO = 21016.945, Lie = 13450.009, Patience = 0/5
#    Epoch   3: Train ELBO = 21403.195, Valid ELBO = 19233.260, Lie = 17026.836, Patience = 0/5
#    Epoch   4: Train ELBO = 19239.990, Valid ELBO = 16929.779, Lie = 18536.824, Patience = 0/5
#    Epoch   5: Train ELBO = 17985.428, Valid ELBO = 15263.300, Lie = 23157.645, Patience = 0/5
#    Epoch   6: Train ELBO = 16806.693, Valid ELBO = 14375.728, Lie = 24146.461, Patience = 0/5
#    Epoch   9: Train ELBO = 15567.480, Valid ELBO = 13790.850, Lie = 9922.536, Patience = 0/5
# 📊 Comprehensive vector field analysis saved: vector_field_plots/perturb_0_2_lambda_1_00e00/vector_field_analysis_epoch_010.png
#    Epoch  10: Train ELBO = 14128.923, Valid ELBO = 11867.509, Lie = 5237.732, Patience = 0/5
#    Epoch  11: Train ELBO = 11393.755, Valid ELBO = 10229.662, Lie = 2212.725, Patience = 0/5
#    Epoch  12: Train ELBO = 9424.925, Valid ELBO = 8176.583, Lie = 1181.708, Patience = 0/5
#    Epoch  13: Train ELBO = 7044.359, Valid ELBO = 6108.864, Lie = 699.173, Patience = 0/5
#    Epoch  14: Train ELBO = 5149.522, Valid ELBO = 4330.282, Lie = 237.525, Patience = 0/5
#    Epoch  15: Train ELBO = 3861.100, Valid ELBO = 3462.114, Lie = 55.664, Patience = 0/5
#    Epoch  16: Train ELBO = 3371.002, Valid ELBO = 3121.580, Lie = 45.898, Patience = 0/5
#    Epoch  17: Train ELBO = 3131.218, Valid ELBO = 3017.371, Lie = 55.377, Patience = 0/5
#    Epoch  18: Train ELBO = 3014.354, Valid ELBO = 2900.257, Lie = 54.158, Patience = 0/5
#    Epoch  19: Train ELBO = 2915.752, Valid ELBO = 2810.799, Lie = 51.896, Patience = 0/5
# 📊 Comprehensive vector field analysis saved: vector_field_plots/perturb_0_2_lambda_1_00e00/vector_field_analysis_epoch_020.png
#    Epoch  20: Train ELBO = 2840.084, Valid ELBO = 2768.812, Lie = 45.281, Patience = 0/5
#    Epoch  21: Train ELBO = 2776.329, Valid ELBO = 2702.047, Lie = 41.846, Patience = 0/5
#    Epoch  22: Train ELBO = 2719.984, Valid ELBO = 2654.755, Lie = 41.621, Patience = 0/5
#    Epoch  23: Train ELBO = 2688.887, Valid ELBO = 2644.244, Lie = 36.496, Patience = 0/5
#    Epoch  24: Train ELBO = 2652.209, Valid ELBO = 2610.290, Lie = 55.403, Patience = 0/5
#    Epoch  25: Train ELBO = 2613.205, Valid ELBO = 2576.760, Lie = 37.606, Patience = 0/5
#    ✅ Restored model with best validation ELBO: 2576.760010
# 📊 Comprehensive vector field analysis saved: vector_field_plots/perturb_0_2_lambda_1_00e00/vector_field_analysis_epoch_025_final.png
# 📊 Comprehensive comparison plot saved: vector_field_plots/perturb_0_2_lambda_1_00e00/comprehensive_comparison.png
# 🎯 All vector field plots saved to: vector_field_plots/perturb_0_2_lambda_1_00e00
#    Final: ELBO = 2556.247, Lie = 38.759, Total = 2595.006
#    📊 Diff from perfect_ring: mean=0.084, max=0.340
#    📊 Diff from perturbed_ring: mean=0.083, max=0.353
#    📊 Diff from target_rotation: mean=0.845, max=1.794
#
# ================================================================================
# 🎯 PERTURBATION MAGNITUDE 0.3 (2/4)
# ================================================================================
#
# --- Training 1/4: λ = 0.00e+00, perturbation = 0.3 ---
# 📁 Vector field plots will be saved to: vector_field_plots/perturb_0_3_lambda_0_00e00
# 🚀 Training with λ_lie = 0.00e+00
#    Max epochs: 25, Patience: 5
#    Early stopping on: validation ELBO loss
# 📊 Comprehensive vector field analysis saved: vector_field_plots/perturb_0_3_lambda_0_00e00/vector_field_analysis_epoch_-01_initial.png
#    Initial: Train ELBO = 21767.273, Valid ELBO = 23320.926, Lie = 0.000
#    Epoch   1: Train ELBO = 21325.588, Valid ELBO = 21451.467, Lie = 0.000, Patience = 0/5
#    Epoch   2: Train ELBO = 19848.658, Valid ELBO = 19509.162, Lie = 0.000, Patience = 0/5
#    Epoch   3: Train ELBO = 13386.720, Valid ELBO = 10094.412, Lie = 0.000, Patience = 0/5
#    Epoch   4: Train ELBO = 8602.740, Valid ELBO = 8821.553, Lie = 0.000, Patience = 0/5
#    Epoch   5: Train ELBO = 7658.223, Valid ELBO = 7453.304, Lie = 0.000, Patience = 0/5
#    Epoch   6: Train ELBO = 5267.936, Valid ELBO = 3884.578, Lie = 0.000, Patience = 0/5
#    Epoch   7: Train ELBO = 3275.126, Valid ELBO = 2916.401, Lie = 0.000, Patience = 0/5
#    Epoch   8: Train ELBO = 2800.855, Valid ELBO = 2719.431, Lie = 0.000, Patience = 0/5
#    Epoch   9: Train ELBO = 2666.363, Valid ELBO = 2653.864, Lie = 0.000, Patience = 0/5
# 📊 Comprehensive vector field analysis saved: vector_field_plots/perturb_0_3_lambda_0_00e00/vector_field_analysis_epoch_010.png
#    Epoch  10: Train ELBO = 2606.879, Valid ELBO = 2584.464, Lie = 0.000, Patience = 0/5
#    Epoch  11: Train ELBO = 2559.809, Valid ELBO = 2559.326, Lie = 0.000, Patience = 0/5
#    Epoch  12: Train ELBO = 2526.803, Valid ELBO = 2518.427, Lie = 0.000, Patience = 0/5
#    Epoch  13: Train ELBO = 2489.606, Valid ELBO = 2499.939, Lie = 0.000, Patience = 0/5
#    Epoch  14: Train ELBO = 2474.054, Valid ELBO = 2466.728, Lie = 0.000, Patience = 0/5
#    Epoch  15: Train ELBO = 2452.038, Valid ELBO = 2445.859, Lie = 0.000, Patience = 0/5
#    Epoch  16: Train ELBO = 2431.270, Valid ELBO = 2432.527, Lie = 0.000, Patience = 0/5
#    Epoch  17: Train ELBO = 2412.357, Valid ELBO = 2416.338, Lie = 0.000, Patience = 0/5
#    Epoch  18: Train ELBO = 2401.533, Valid ELBO = 2398.718, Lie = 0.000, Patience = 0/5
#    Epoch  19: Train ELBO = 2389.570, Valid ELBO = 2395.193, Lie = 0.000, Patience = 0/5
# 📊 Comprehensive vector field analysis saved: vector_field_plots/perturb_0_3_lambda_0_00e00/vector_field_analysis_epoch_020.png
#    Epoch  20: Train ELBO = 2379.006, Valid ELBO = 2377.283, Lie = 0.000, Patience = 0/5
#    Epoch  21: Train ELBO = 2366.441, Valid ELBO = 2365.971, Lie = 0.000, Patience = 0/5
#    Epoch  22: Train ELBO = 2359.281, Valid ELBO = 2359.609, Lie = 0.000, Patience = 0/5
#    Epoch  23: Train ELBO = 2350.007, Valid ELBO = 2351.104, Lie = 0.000, Patience = 0/5
#    Epoch  25: Train ELBO = 2339.940, Valid ELBO = 2347.458, Lie = 0.000, Patience = 0/5
#    ✅ Restored model with best validation ELBO: 2347.457520
# 📊 Comprehensive vector field analysis saved: vector_field_plots/perturb_0_3_lambda_0_00e00/vector_field_analysis_epoch_025_final.png
# 📊 Comprehensive comparison plot saved: vector_field_plots/perturb_0_3_lambda_0_00e00/comprehensive_comparison.png
# 🎯 All vector field plots saved to: vector_field_plots/perturb_0_3_lambda_0_00e00
#    Final: ELBO = 2344.236, Lie = 0.000, Total = 2344.236
#    📊 Diff from perfect_ring: mean=0.086, max=0.461
#    📊 Diff from perturbed_ring: mean=0.083, max=0.491
#    📊 Diff from target_rotation: mean=0.832, max=1.742
#
# --- Training 2/4: λ = 1.00e-04, perturbation = 0.3 ---
# 📁 Vector field plots will be saved to: vector_field_plots/perturb_0_3_lambda_1_00eneg04
# 🚀 Training with λ_lie = 1.00e-04
#    Max epochs: 25, Patience: 5
#    Early stopping on: validation ELBO loss
# 📊 Comprehensive vector field analysis saved: vector_field_plots/perturb_0_3_lambda_1_00eneg04/vector_field_analysis_epoch_-01_initial.png
#    Initial: Train ELBO = 21767.834, Valid ELBO = 23319.988, Lie = 9129143.000
#    Epoch   1: Train ELBO = 21321.375, Valid ELBO = 21413.273, Lie = 183558.891, Patience = 0/5
#    Epoch   2: Train ELBO = 19718.203, Valid ELBO = 19031.713, Lie = 23702.863, Patience = 0/5
#    Epoch   3: Train ELBO = 13088.968, Valid ELBO = 10630.536, Lie = 79203.148, Patience = 0/5
#    Epoch   4: Train ELBO = 8875.386, Valid ELBO = 8999.810, Lie = 42495.680, Patience = 0/5
#    Epoch   5: Train ELBO = 7887.917, Valid ELBO = 7891.571, Lie = 15871.844, Patience = 0/5
#    Epoch   6: Train ELBO = 6000.996, Valid ELBO = 4864.485, Lie = 2487.555, Patience = 0/5
#    Epoch   7: Train ELBO = 3756.300, Valid ELBO = 3137.919, Lie = 356.163, Patience = 0/5
#    Epoch   8: Train ELBO = 2891.284, Valid ELBO = 2768.511, Lie = 98.342, Patience = 0/5
#    Epoch   9: Train ELBO = 2686.996, Valid ELBO = 2679.678, Lie = 76.676, Patience = 0/5
# 📊 Comprehensive vector field analysis saved: vector_field_plots/perturb_0_3_lambda_1_00eneg04/vector_field_analysis_epoch_010.png
#    Epoch  10: Train ELBO = 2612.597, Valid ELBO = 2591.613, Lie = 107.878, Patience = 0/5
#    Epoch  11: Train ELBO = 2567.027, Valid ELBO = 2568.185, Lie = 149.584, Patience = 0/5
#    Epoch  12: Train ELBO = 2534.345, Valid ELBO = 2535.980, Lie = 82.863, Patience = 0/5
#    Epoch  13: Train ELBO = 2501.638, Valid ELBO = 2498.284, Lie = 48.421, Patience = 0/5
#    Epoch  14: Train ELBO = 2475.923, Valid ELBO = 2465.453, Lie = 56.160, Patience = 0/5
#    Epoch  15: Train ELBO = 2455.056, Valid ELBO = 2449.502, Lie = 53.487, Patience = 0/5
#    Epoch  16: Train ELBO = 2427.946, Valid ELBO = 2425.326, Lie = 64.165, Patience = 0/5
#    Epoch  17: Train ELBO = 2410.699, Valid ELBO = 2409.695, Lie = 70.441, Patience = 0/5
#    Epoch  18: Train ELBO = 2397.434, Valid ELBO = 2392.205, Lie = 58.811, Patience = 0/5
#    Epoch  19: Train ELBO = 2386.534, Valid ELBO = 2389.614, Lie = 67.178, Patience = 0/5
# 📊 Comprehensive vector field analysis saved: vector_field_plots/perturb_0_3_lambda_1_00eneg04/vector_field_analysis_epoch_020.png
#    Epoch  20: Train ELBO = 2377.233, Valid ELBO = 2372.278, Lie = 47.316, Patience = 0/5
#    Epoch  21: Train ELBO = 2364.943, Valid ELBO = 2365.648, Lie = 61.572, Patience = 0/5
#    Epoch  22: Train ELBO = 2355.124, Valid ELBO = 2360.709, Lie = 41.953, Patience = 0/5
#    Epoch  24: Train ELBO = 2345.044, Valid ELBO = 2357.208, Lie = 65.430, Patience = 0/5
#    Epoch  25: Train ELBO = 2340.672, Valid ELBO = 2341.720, Lie = 77.487, Patience = 0/5
#    ✅ Restored model with best validation ELBO: 2341.719727
# 📊 Comprehensive vector field analysis saved: vector_field_plots/perturb_0_3_lambda_1_00eneg04/vector_field_analysis_epoch_025_final.png
# 📊 Comprehensive comparison plot saved: vector_field_plots/perturb_0_3_lambda_1_00eneg04/comprehensive_comparison.png
# 🎯 All vector field plots saved to: vector_field_plots/perturb_0_3_lambda_1_00eneg04
#    Final: ELBO = 2338.535, Lie = 57.640, Total = 2338.541
#    📊 Diff from perfect_ring: mean=0.087, max=0.467
#    📊 Diff from perturbed_ring: mean=0.086, max=0.497
#    📊 Diff from target_rotation: mean=0.831, max=1.716
#
# --- Training 3/4: λ = 1.00e-02, perturbation = 0.3 ---
# 📁 Vector field plots will be saved to: vector_field_plots/perturb_0_3_lambda_1_00eneg02
# 🚀 Training with λ_lie = 1.00e-02
#    Max epochs: 25, Patience: 5
#    Early stopping on: validation ELBO loss
# 📊 Comprehensive vector field analysis saved: vector_field_plots/perturb_0_3_lambda_1_00eneg02/vector_field_analysis_epoch_-01_initial.png
#    Initial: Train ELBO = 21768.705, Valid ELBO = 23318.561, Lie = 9098515.000
#    Epoch   1: Train ELBO = 21573.727, Valid ELBO = 21436.535, Lie = 52964.414, Patience = 0/5
#    Epoch   2: Train ELBO = 19681.693, Valid ELBO = 18368.520, Lie = 37705.078, Patience = 0/5
#    Epoch   3: Train ELBO = 13062.880, Valid ELBO = 11543.147, Lie = 121934.883, Patience = 0/5
#    Epoch   4: Train ELBO = 9840.030, Valid ELBO = 9982.964, Lie = 120545.445, Patience = 0/5
#    Epoch   5: Train ELBO = 8741.504, Valid ELBO = 9142.521, Lie = 101333.297, Patience = 0/5
#    Epoch   6: Train ELBO = 8238.662, Valid ELBO = 8752.815, Lie = 88731.609, Patience = 0/5
#    Epoch   7: Train ELBO = 7803.288, Valid ELBO = 8196.879, Lie = 101943.781, Patience = 0/5
#    Epoch   8: Train ELBO = 7186.105, Valid ELBO = 7557.109, Lie = 104975.078, Patience = 0/5
#    Epoch   9: Train ELBO = 6437.518, Valid ELBO = 6606.487, Lie = 104782.000, Patience = 0/5
# 📊 Comprehensive vector field analysis saved: vector_field_plots/perturb_0_3_lambda_1_00eneg02/vector_field_analysis_epoch_010.png
#    Epoch  10: Train ELBO = 5476.518, Valid ELBO = 5478.069, Lie = 86864.133, Patience = 0/5
#    Epoch  11: Train ELBO = 4695.318, Valid ELBO = 4866.255, Lie = 144447.062, Patience = 0/5
#    Epoch  12: Train ELBO = 4274.277, Valid ELBO = 4473.960, Lie = 98180.359, Patience = 0/5
#    Epoch  13: Train ELBO = 3986.001, Valid ELBO = 4101.955, Lie = 130953.133, Patience = 0/5
#    Epoch  14: Train ELBO = 3758.886, Valid ELBO = 3949.275, Lie = 45172.328, Patience = 0/5
#    Epoch  15: Train ELBO = 3442.656, Valid ELBO = 3551.611, Lie = 104525.695, Patience = 0/5
#    Epoch  16: Train ELBO = 3206.914, Valid ELBO = 3213.149, Lie = 66062.453, Patience = 0/5
#    Epoch  17: Train ELBO = 2928.987, Valid ELBO = 2832.213, Lie = 28036.816, Patience = 0/5
#    Epoch  18: Train ELBO = 2640.196, Valid ELBO = 2563.807, Lie = 7574.201, Patience = 0/5
#    Epoch  19: Train ELBO = 2492.813, Valid ELBO = 2465.863, Lie = 2678.086, Patience = 0/5
# 📊 Comprehensive vector field analysis saved: vector_field_plots/perturb_0_3_lambda_1_00eneg02/vector_field_analysis_epoch_020.png
#    Epoch  20: Train ELBO = 2432.183, Valid ELBO = 2429.818, Lie = 856.124, Patience = 0/5
#    Epoch  21: Train ELBO = 2407.083, Valid ELBO = 2403.110, Lie = 383.701, Patience = 0/5
#    Epoch  22: Train ELBO = 2388.413, Valid ELBO = 2380.770, Lie = 241.747, Patience = 0/5
#    Epoch  24: Train ELBO = 2366.190, Valid ELBO = 2367.700, Lie = 119.603, Patience = 0/5
#    Epoch  25: Train ELBO = 2358.242, Valid ELBO = 2356.779, Lie = 94.207, Patience = 0/5
#    ✅ Restored model with best validation ELBO: 2356.778564
# 📊 Comprehensive vector field analysis saved: vector_field_plots/perturb_0_3_lambda_1_00eneg02/vector_field_analysis_epoch_025_final.png
# 📊 Comprehensive comparison plot saved: vector_field_plots/perturb_0_3_lambda_1_00eneg02/comprehensive_comparison.png
# 🎯 All vector field plots saved to: vector_field_plots/perturb_0_3_lambda_1_00eneg02
#    Final: ELBO = 2353.529, Lie = 91.125, Total = 2354.440
#    📊 Diff from perfect_ring: mean=0.133, max=0.798
#    📊 Diff from perturbed_ring: mean=0.130, max=0.770
#    📊 Diff from target_rotation: mean=0.817, max=1.861
#
# --- Training 4/4: λ = 1.00e+00, perturbation = 0.3 ---
# 📁 Vector field plots will be saved to: vector_field_plots/perturb_0_3_lambda_1_00e00
# 🚀 Training with λ_lie = 1.00e+00
#    Max epochs: 25, Patience: 5
#    Early stopping on: validation ELBO loss
# 📊 Comprehensive vector field analysis saved: vector_field_plots/perturb_0_3_lambda_1_00e00/vector_field_analysis_epoch_-01_initial.png
#    Initial: Train ELBO = 21769.361, Valid ELBO = 23316.369, Lie = 9093144.000
#    Epoch   1: Train ELBO = 22184.828, Valid ELBO = 22847.387, Lie = 21895.635, Patience = 0/5
#    Epoch   2: Train ELBO = 21526.668, Valid ELBO = 20802.123, Lie = 11359.479, Patience = 0/5
#    Epoch   3: Train ELBO = 18234.703, Valid ELBO = 17177.326, Lie = 17746.689, Patience = 0/5
#    Epoch   4: Train ELBO = 15161.710, Valid ELBO = 15190.836, Lie = 51016.859, Patience = 0/5
#    Epoch   5: Train ELBO = 14012.005, Valid ELBO = 14430.731, Lie = 19205.947, Patience = 0/5
#    Epoch   7: Train ELBO = 12756.416, Valid ELBO = 13495.378, Lie = 10621.262, Patience = 0/5
#    Epoch   8: Train ELBO = 11307.492, Valid ELBO = 11225.810, Lie = 7267.301, Patience = 0/5
#    Epoch   9: Train ELBO = 9517.734, Valid ELBO = 9740.276, Lie = 3567.009, Patience = 0/5
# 📊 Comprehensive vector field analysis saved: vector_field_plots/perturb_0_3_lambda_1_00e00/vector_field_analysis_epoch_010.png
#    Epoch  10: Train ELBO = 8372.352, Valid ELBO = 8572.182, Lie = 3509.652, Patience = 0/5
#    Epoch  11: Train ELBO = 7180.452, Valid ELBO = 6713.834, Lie = 2060.904, Patience = 0/5
#    Epoch  12: Train ELBO = 5700.564, Valid ELBO = 5358.081, Lie = 726.345, Patience = 0/5
#    Epoch  13: Train ELBO = 4618.250, Valid ELBO = 4323.057, Lie = 197.597, Patience = 0/5
#    Epoch  14: Train ELBO = 3869.634, Valid ELBO = 3657.235, Lie = 150.854, Patience = 0/5
#    Epoch  15: Train ELBO = 3475.743, Valid ELBO = 3353.900, Lie = 93.286, Patience = 0/5
#    Epoch  16: Train ELBO = 3216.752, Valid ELBO = 3099.689, Lie = 203.929, Patience = 0/5
#    Epoch  17: Train ELBO = 3039.687, Valid ELBO = 2974.866, Lie = 91.676, Patience = 0/5
#    Epoch  18: Train ELBO = 2902.748, Valid ELBO = 2888.009, Lie = 69.030, Patience = 0/5
#    Epoch  19: Train ELBO = 2859.703, Valid ELBO = 2812.541, Lie = 54.221, Patience = 0/5
# 📊 Comprehensive vector field analysis saved: vector_field_plots/perturb_0_3_lambda_1_00e00/vector_field_analysis_epoch_020.png
#    Epoch  20: Train ELBO = 2780.759, Valid ELBO = 2758.381, Lie = 42.979, Patience = 0/5
#    Epoch  21: Train ELBO = 2738.776, Valid ELBO = 2731.880, Lie = 45.191, Patience = 0/5
#    Epoch  22: Train ELBO = 2689.721, Valid ELBO = 2662.761, Lie = 27.549, Patience = 0/5
#    Epoch  23: Train ELBO = 2643.796, Valid ELBO = 2627.888, Lie = 35.860, Patience = 0/5
#    Epoch  25: Train ELBO = 2592.460, Valid ELBO = 2568.754, Lie = 78.441, Patience = 0/5
#    ✅ Restored model with best validation ELBO: 2568.753906
# 📊 Comprehensive vector field analysis saved: vector_field_plots/perturb_0_3_lambda_1_00e00/vector_field_analysis_epoch_025_final.png
# 📊 Comprehensive comparison plot saved: vector_field_plots/perturb_0_3_lambda_1_00e00/comprehensive_comparison.png
# 🎯 All vector field plots saved to: vector_field_plots/perturb_0_3_lambda_1_00e00
#    Final: ELBO = 2563.759, Lie = 53.900, Total = 2617.659
#    📊 Diff from perfect_ring: mean=0.070, max=0.385
#    📊 Diff from perturbed_ring: mean=0.068, max=0.415
#    📊 Diff from target_rotation: mean=0.824, max=1.705
#
# ================================================================================
# 🎯 PERTURBATION MAGNITUDE 0.4 (3/4)
# ================================================================================
#
# --- Training 1/4: λ = 0.00e+00, perturbation = 0.4 ---
# 📁 Vector field plots will be saved to: vector_field_plots/perturb_0_4_lambda_0_00e00
# 🚀 Training with λ_lie = 0.00e+00
#    Max epochs: 25, Patience: 5
#    Early stopping on: validation ELBO loss
# 📊 Comprehensive vector field analysis saved: vector_field_plots/perturb_0_4_lambda_0_00e00/vector_field_analysis_epoch_-01_initial.png
#    Initial: Train ELBO = 20110.664, Valid ELBO = 18047.223, Lie = 0.000
#    Epoch   1: Train ELBO = 15865.657, Valid ELBO = 14047.551, Lie = 0.000, Patience = 0/5
#    Epoch   2: Train ELBO = 14233.979, Valid ELBO = 13041.949, Lie = 0.000, Patience = 0/5
#    Epoch   3: Train ELBO = 11966.634, Valid ELBO = 9931.094, Lie = 0.000, Patience = 0/5
#    Epoch   4: Train ELBO = 9951.878, Valid ELBO = 8592.799, Lie = 0.000, Patience = 0/5
#    Epoch   5: Train ELBO = 8135.716, Valid ELBO = 6302.998, Lie = 0.000, Patience = 0/5
#    Epoch   6: Train ELBO = 5384.061, Valid ELBO = 3547.901, Lie = 0.000, Patience = 0/5
#    Epoch   7: Train ELBO = 3116.198, Valid ELBO = 2781.328, Lie = 0.000, Patience = 0/5
#    Epoch   8: Train ELBO = 2689.676, Valid ELBO = 2614.209, Lie = 0.000, Patience = 0/5
#    Epoch   9: Train ELBO = 2574.674, Valid ELBO = 2528.122, Lie = 0.000, Patience = 0/5
# 📊 Comprehensive vector field analysis saved: vector_field_plots/perturb_0_4_lambda_0_00e00/vector_field_analysis_epoch_010.png
#    Epoch  10: Train ELBO = 2512.596, Valid ELBO = 2494.266, Lie = 0.000, Patience = 0/5
#    Epoch  11: Train ELBO = 2471.719, Valid ELBO = 2447.467, Lie = 0.000, Patience = 0/5
#    Epoch  12: Train ELBO = 2437.448, Valid ELBO = 2421.853, Lie = 0.000, Patience = 0/5
#    Epoch  13: Train ELBO = 2414.219, Valid ELBO = 2393.625, Lie = 0.000, Patience = 0/5
#    Epoch  14: Train ELBO = 2396.501, Valid ELBO = 2379.282, Lie = 0.000, Patience = 0/5
#    Epoch  15: Train ELBO = 2383.250, Valid ELBO = 2362.788, Lie = 0.000, Patience = 0/5
#    Epoch  16: Train ELBO = 2364.267, Valid ELBO = 2362.273, Lie = 0.000, Patience = 0/5
#    Epoch  17: Train ELBO = 2354.301, Valid ELBO = 2340.473, Lie = 0.000, Patience = 0/5
#    Epoch  18: Train ELBO = 2342.515, Valid ELBO = 2327.719, Lie = 0.000, Patience = 0/5
#    Epoch  19: Train ELBO = 2330.001, Valid ELBO = 2320.689, Lie = 0.000, Patience = 0/5
# 📊 Comprehensive vector field analysis saved: vector_field_plots/perturb_0_4_lambda_0_00e00/vector_field_analysis_epoch_020.png
#    Epoch  20: Train ELBO = 2324.386, Valid ELBO = 2317.024, Lie = 0.000, Patience = 0/5
#    Epoch  21: Train ELBO = 2317.491, Valid ELBO = 2312.667, Lie = 0.000, Patience = 0/5
#    Epoch  22: Train ELBO = 2312.969, Valid ELBO = 2306.247, Lie = 0.000, Patience = 0/5
#    Epoch  23: Train ELBO = 2307.438, Valid ELBO = 2301.393, Lie = 0.000, Patience = 0/5
#    Epoch  24: Train ELBO = 2299.687, Valid ELBO = 2299.219, Lie = 0.000, Patience = 0/5
#    Epoch  25: Train ELBO = 2295.703, Valid ELBO = 2289.890, Lie = 0.000, Patience = 0/5
#    ✅ Restored model with best validation ELBO: 2289.890137
# 📊 Comprehensive vector field analysis saved: vector_field_plots/perturb_0_4_lambda_0_00e00/vector_field_analysis_epoch_025_final.png
# 📊 Comprehensive comparison plot saved: vector_field_plots/perturb_0_4_lambda_0_00e00/comprehensive_comparison.png
# 🎯 All vector field plots saved to: vector_field_plots/perturb_0_4_lambda_0_00e00
#    Final: ELBO = 2289.106, Lie = 0.000, Total = 2289.106
#    📊 Diff from perfect_ring: mean=0.092, max=0.567
#    📊 Diff from perturbed_ring: mean=0.089, max=0.553
#    📊 Diff from target_rotation: mean=0.829, max=1.891
#
# --- Training 2/4: λ = 1.00e-04, perturbation = 0.4 ---
# 📁 Vector field plots will be saved to: vector_field_plots/perturb_0_4_lambda_1_00eneg04
# 🚀 Training with λ_lie = 1.00e-04
#    Max epochs: 25, Patience: 5
#    Early stopping on: validation ELBO loss
# 📊 Comprehensive vector field analysis saved: vector_field_plots/perturb_0_4_lambda_1_00eneg04/vector_field_analysis_epoch_-01_initial.png
#    Initial: Train ELBO = 20113.338, Valid ELBO = 18049.836, Lie = 9106209.000
#    Epoch   1: Train ELBO = 15943.062, Valid ELBO = 14073.784, Lie = 177311.719, Patience = 0/5
#    Epoch   2: Train ELBO = 14205.338, Valid ELBO = 12925.155, Lie = 95067.305, Patience = 0/5
#    Epoch   3: Train ELBO = 11731.085, Valid ELBO = 9844.326, Lie = 97807.133, Patience = 0/5
#    Epoch   4: Train ELBO = 9871.321, Valid ELBO = 8460.379, Lie = 101322.703, Patience = 0/5
#    Epoch   5: Train ELBO = 8315.499, Valid ELBO = 6868.559, Lie = 22787.660, Patience = 0/5
#    Epoch   6: Train ELBO = 6743.166, Valid ELBO = 5643.917, Lie = 10362.852, Patience = 0/5
#    Epoch   7: Train ELBO = 4909.155, Valid ELBO = 3673.759, Lie = 960.141, Patience = 0/5
#    Epoch   8: Train ELBO = 3122.366, Valid ELBO = 2688.241, Lie = 164.115, Patience = 0/5
#    Epoch   9: Train ELBO = 2625.083, Valid ELBO = 2562.979, Lie = 95.650, Patience = 0/5
# 📊 Comprehensive vector field analysis saved: vector_field_plots/perturb_0_4_lambda_1_00eneg04/vector_field_analysis_epoch_010.png
#    Epoch  10: Train ELBO = 2533.745, Valid ELBO = 2512.704, Lie = 110.943, Patience = 0/5
#    Epoch  11: Train ELBO = 2482.357, Valid ELBO = 2455.744, Lie = 118.815, Patience = 0/5
#    Epoch  12: Train ELBO = 2442.028, Valid ELBO = 2427.141, Lie = 87.196, Patience = 0/5
#    Epoch  13: Train ELBO = 2418.967, Valid ELBO = 2405.153, Lie = 217.349, Patience = 0/5
#    Epoch  14: Train ELBO = 2398.643, Valid ELBO = 2375.429, Lie = 91.316, Patience = 0/5
#    Epoch  15: Train ELBO = 2380.687, Valid ELBO = 2363.940, Lie = 124.166, Patience = 0/5
#    Epoch  16: Train ELBO = 2363.141, Valid ELBO = 2357.833, Lie = 144.659, Patience = 0/5
#    Epoch  17: Train ELBO = 2351.756, Valid ELBO = 2341.084, Lie = 152.040, Patience = 0/5
#    Epoch  18: Train ELBO = 2341.272, Valid ELBO = 2333.825, Lie = 118.776, Patience = 0/5
#    Epoch  19: Train ELBO = 2334.080, Valid ELBO = 2326.046, Lie = 150.997, Patience = 0/5
# 📊 Comprehensive vector field analysis saved: vector_field_plots/perturb_0_4_lambda_1_00eneg04/vector_field_analysis_epoch_020.png
#    Epoch  20: Train ELBO = 2325.061, Valid ELBO = 2318.018, Lie = 140.153, Patience = 0/5
#    Epoch  21: Train ELBO = 2320.880, Valid ELBO = 2317.554, Lie = 187.537, Patience = 0/5
#    Epoch  22: Train ELBO = 2314.985, Valid ELBO = 2309.283, Lie = 210.448, Patience = 0/5
#    Epoch  23: Train ELBO = 2307.933, Valid ELBO = 2301.385, Lie = 145.805, Patience = 0/5
#    Epoch  24: Train ELBO = 2299.602, Valid ELBO = 2298.719, Lie = 134.007, Patience = 0/5
#    Epoch  25: Train ELBO = 2294.761, Valid ELBO = 2289.132, Lie = 149.807, Patience = 0/5
#    ✅ Restored model with best validation ELBO: 2289.132080
# 📊 Comprehensive vector field analysis saved: vector_field_plots/perturb_0_4_lambda_1_00eneg04/vector_field_analysis_epoch_025_final.png
# 📊 Comprehensive comparison plot saved: vector_field_plots/perturb_0_4_lambda_1_00eneg04/comprehensive_comparison.png
# 🎯 All vector field plots saved to: vector_field_plots/perturb_0_4_lambda_1_00eneg04
#    Final: ELBO = 2288.354, Lie = 112.732, Total = 2288.365
#    📊 Diff from perfect_ring: mean=0.089, max=0.562
#    📊 Diff from perturbed_ring: mean=0.085, max=0.550
#    📊 Diff from target_rotation: mean=0.819, max=1.861
#
# --- Training 3/4: λ = 1.00e-02, perturbation = 0.4 ---
# 📁 Vector field plots will be saved to: vector_field_plots/perturb_0_4_lambda_1_00eneg02
# 🚀 Training with λ_lie = 1.00e-02
#    Max epochs: 25, Patience: 5
#    Early stopping on: validation ELBO loss
# 📊 Comprehensive vector field analysis saved: vector_field_plots/perturb_0_4_lambda_1_00eneg02/vector_field_analysis_epoch_-01_initial.png
#    Initial: Train ELBO = 20115.660, Valid ELBO = 18051.912, Lie = 9154202.000
#    Epoch   1: Train ELBO = 17733.803, Valid ELBO = 15721.219, Lie = 304983.438, Patience = 0/5
#    Epoch   2: Train ELBO = 14917.588, Valid ELBO = 13569.647, Lie = 53639.480, Patience = 0/5
#    Epoch   3: Train ELBO = 12757.527, Valid ELBO = 10878.318, Lie = 55154.684, Patience = 0/5
#    Epoch   4: Train ELBO = 10278.769, Valid ELBO = 8767.813, Lie = 71070.789, Patience = 0/5
#    Epoch   5: Train ELBO = 8912.237, Valid ELBO = 7751.500, Lie = 52871.348, Patience = 0/5
#    Epoch   6: Train ELBO = 8037.687, Valid ELBO = 7082.007, Lie = 43005.668, Patience = 0/5
#    Epoch   7: Train ELBO = 7261.701, Valid ELBO = 6626.929, Lie = 38238.684, Patience = 0/5
# 📊 Comprehensive vector field analysis saved: vector_field_plots/perturb_0_4_lambda_1_00eneg02/vector_field_analysis_epoch_010.png
#    Epoch  10: Train ELBO = 11680.142, Valid ELBO = 11101.199, Lie = 988488.938, Patience = 3/5
#    Epoch  17: Train ELBO = 7432.238, Valid ELBO = 6404.701, Lie = 37387.203, Patience = 0/5
#    Epoch  18: Train ELBO = 6628.522, Valid ELBO = 6085.975, Lie = 31272.906, Patience = 0/5
#    Epoch  19: Train ELBO = 6053.143, Valid ELBO = 5520.764, Lie = 20520.957, Patience = 0/5
# 📊 Comprehensive vector field analysis saved: vector_field_plots/perturb_0_4_lambda_1_00eneg02/vector_field_analysis_epoch_020.png
#    Epoch  20: Train ELBO = 5063.600, Valid ELBO = 4083.813, Lie = 2865.521, Patience = 0/5
#    Epoch  21: Train ELBO = 3443.462, Valid ELBO = 2826.316, Lie = 414.111, Patience = 0/5
#    Epoch  22: Train ELBO = 2702.936, Valid ELBO = 2579.018, Lie = 203.241, Patience = 0/5
#    Epoch  23: Train ELBO = 2542.658, Valid ELBO = 2493.854, Lie = 193.376, Patience = 0/5
#    Epoch  24: Train ELBO = 2470.985, Valid ELBO = 2449.101, Lie = 115.292, Patience = 0/5
#    Epoch  25: Train ELBO = 2431.633, Valid ELBO = 2419.970, Lie = 131.294, Patience = 0/5
#    ✅ Restored model with best validation ELBO: 2419.970215
# 📊 Comprehensive vector field analysis saved: vector_field_plots/perturb_0_4_lambda_1_00eneg02/vector_field_analysis_epoch_025_final.png
# 📊 Comprehensive comparison plot saved: vector_field_plots/perturb_0_4_lambda_1_00eneg02/comprehensive_comparison.png
# 🎯 All vector field plots saved to: vector_field_plots/perturb_0_4_lambda_1_00eneg02
#    Final: ELBO = 2418.219, Lie = 162.092, Total = 2419.840
#    📊 Diff from perfect_ring: mean=0.092, max=0.545
#    📊 Diff from perturbed_ring: mean=0.089, max=0.528
#    📊 Diff from target_rotation: mean=0.786, max=1.898
#
# --- Training 4/4: λ = 1.00e+00, perturbation = 0.4 ---
# 📁 Vector field plots will be saved to: vector_field_plots/perturb_0_4_lambda_1_00e00
# 🚀 Training with λ_lie = 1.00e+00
#    Max epochs: 25, Patience: 5
#    Early stopping on: validation ELBO loss
# 📊 Comprehensive vector field analysis saved: vector_field_plots/perturb_0_4_lambda_1_00e00/vector_field_analysis_epoch_-01_initial.png
#    Initial: Train ELBO = 20116.023, Valid ELBO = 18053.359, Lie = 9152764.000
#    Epoch   1: Train ELBO = 19931.090, Valid ELBO = 20713.229, Lie = 26272.682, Patience = 0/5
#    Epoch   2: Train ELBO = 20031.771, Valid ELBO = 19551.686, Lie = 12974.007, Patience = 0/5
#    Epoch   3: Train ELBO = 19460.090, Valid ELBO = 18733.490, Lie = 14645.773, Patience = 0/5
#    Epoch   4: Train ELBO = 19112.859, Valid ELBO = 18537.367, Lie = 12397.065, Patience = 0/5
#    Epoch   5: Train ELBO = 18681.953, Valid ELBO = 18354.846, Lie = 11703.235, Patience = 0/5
#    Epoch   6: Train ELBO = 18466.926, Valid ELBO = 17928.707, Lie = 12307.656, Patience = 0/5
#    Epoch   7: Train ELBO = 18231.287, Valid ELBO = 17665.537, Lie = 25173.039, Patience = 0/5
#    Epoch   8: Train ELBO = 17581.039, Valid ELBO = 16774.295, Lie = 9562.675, Patience = 0/5
#    Epoch   9: Train ELBO = 16404.199, Valid ELBO = 14748.821, Lie = 15058.215, Patience = 0/5
# 📊 Comprehensive vector field analysis saved: vector_field_plots/perturb_0_4_lambda_1_00e00/vector_field_analysis_epoch_010.png
#    Epoch  10: Train ELBO = 11368.482, Valid ELBO = 7870.379, Lie = 5475.455, Patience = 0/5
#    Epoch  11: Train ELBO = 7222.341, Valid ELBO = 5949.292, Lie = 689.290, Patience = 0/5
#    Epoch  12: Train ELBO = 5652.418, Valid ELBO = 5246.828, Lie = 194.225, Patience = 0/5
#    Epoch  13: Train ELBO = 4839.591, Valid ELBO = 4453.584, Lie = 123.019, Patience = 0/5
#    Epoch  14: Train ELBO = 4116.968, Valid ELBO = 3857.127, Lie = 50.327, Patience = 0/5
#    Epoch  15: Train ELBO = 3637.579, Valid ELBO = 3415.732, Lie = 70.018, Patience = 0/5
#    Epoch  16: Train ELBO = 3362.093, Valid ELBO = 3241.024, Lie = 60.960, Patience = 0/5
#    Epoch  17: Train ELBO = 3160.675, Valid ELBO = 3124.322, Lie = 57.836, Patience = 0/5
#    Epoch  18: Train ELBO = 3048.519, Valid ELBO = 3018.091, Lie = 58.442, Patience = 0/5
#    Epoch  19: Train ELBO = 2937.373, Valid ELBO = 2932.423, Lie = 105.035, Patience = 0/5
# 📊 Comprehensive vector field analysis saved: vector_field_plots/perturb_0_4_lambda_1_00e00/vector_field_analysis_epoch_020.png
#    Epoch  20: Train ELBO = 2898.226, Valid ELBO = 2848.591, Lie = 42.365, Patience = 0/5
#    Epoch  21: Train ELBO = 2822.240, Valid ELBO = 2830.268, Lie = 27.474, Patience = 0/5
#    Epoch  22: Train ELBO = 2764.390, Valid ELBO = 2703.541, Lie = 41.374, Patience = 0/5
#    Epoch  24: Train ELBO = 2669.966, Valid ELBO = 2647.090, Lie = 53.703, Patience = 0/5
#    Epoch  25: Train ELBO = 2628.273, Valid ELBO = 2629.558, Lie = 59.523, Patience = 0/5
#    ✅ Restored model with best validation ELBO: 2629.558105
# 📊 Comprehensive vector field analysis saved: vector_field_plots/perturb_0_4_lambda_1_00e00/vector_field_analysis_epoch_025_final.png
# 📊 Comprehensive comparison plot saved: vector_field_plots/perturb_0_4_lambda_1_00e00/comprehensive_comparison.png
# 🎯 All vector field plots saved to: vector_field_plots/perturb_0_4_lambda_1_00e00
#    Final: ELBO = 2624.281, Lie = 50.756, Total = 2675.037
#    📊 Diff from perfect_ring: mean=0.082, max=0.435
#    📊 Diff from perturbed_ring: mean=0.084, max=0.415
#    📊 Diff from target_rotation: mean=0.841, max=1.831
#
# ================================================================================
# 🎯 PERTURBATION MAGNITUDE 0.5 (4/4)
# ================================================================================
#
# --- Training 1/4: λ = 0.00e+00, perturbation = 0.5 ---
# 📁 Vector field plots will be saved to: vector_field_plots/perturb_0_5_lambda_0_00e00
# 🚀 Training with λ_lie = 0.00e+00
#    Max epochs: 25, Patience: 5
#    Early stopping on: validation ELBO loss
# 📊 Comprehensive vector field analysis saved: vector_field_plots/perturb_0_5_lambda_0_00e00/vector_field_analysis_epoch_-01_initial.png
#    Initial: Train ELBO = 32874.672, Valid ELBO = 33099.754, Lie = 0.000
#    Epoch   1: Train ELBO = 32122.010, Valid ELBO = 31536.180, Lie = 0.000, Patience = 0/5
#    Epoch   2: Train ELBO = 30291.855, Valid ELBO = 27080.836, Lie = 0.000, Patience = 0/5
#    Epoch   3: Train ELBO = 15664.900, Valid ELBO = 8511.438, Lie = 0.000, Patience = 0/5
#    Epoch   4: Train ELBO = 6511.755, Valid ELBO = 5237.653, Lie = 0.000, Patience = 0/5
#    Epoch   5: Train ELBO = 5119.775, Valid ELBO = 4954.154, Lie = 0.000, Patience = 0/5
#    Epoch   6: Train ELBO = 4754.370, Valid ELBO = 4574.994, Lie = 0.000, Patience = 0/5
#    Epoch   7: Train ELBO = 4300.150, Valid ELBO = 4178.542, Lie = 0.000, Patience = 0/5
#    Epoch   8: Train ELBO = 3682.994, Valid ELBO = 3543.602, Lie = 0.000, Patience = 0/5
#    Epoch   9: Train ELBO = 3038.587, Valid ELBO = 2788.649, Lie = 0.000, Patience = 0/5
# 📊 Comprehensive vector field analysis saved: vector_field_plots/perturb_0_5_lambda_0_00e00/vector_field_analysis_epoch_010.png
#    Epoch  10: Train ELBO = 2672.068, Valid ELBO = 2614.239, Lie = 0.000, Patience = 0/5
#    Epoch  11: Train ELBO = 2578.488, Valid ELBO = 2568.433, Lie = 0.000, Patience = 0/5
#    Epoch  12: Train ELBO = 2516.315, Valid ELBO = 2522.294, Lie = 0.000, Patience = 0/5
#    Epoch  13: Train ELBO = 2477.157, Valid ELBO = 2481.984, Lie = 0.000, Patience = 0/5
#    Epoch  14: Train ELBO = 2452.979, Valid ELBO = 2455.080, Lie = 0.000, Patience = 0/5
#    Epoch  15: Train ELBO = 2429.842, Valid ELBO = 2423.556, Lie = 0.000, Patience = 0/5
#    Epoch  16: Train ELBO = 2410.876, Valid ELBO = 2413.509, Lie = 0.000, Patience = 0/5
#    Epoch  17: Train ELBO = 2398.567, Valid ELBO = 2391.792, Lie = 0.000, Patience = 0/5
#    Epoch  19: Train ELBO = 2375.519, Valid ELBO = 2377.482, Lie = 0.000, Patience = 0/5
# 📊 Comprehensive vector field analysis saved: vector_field_plots/perturb_0_5_lambda_0_00e00/vector_field_analysis_epoch_020.png
#    Epoch  20: Train ELBO = 2368.149, Valid ELBO = 2369.405, Lie = 0.000, Patience = 0/5
#    Epoch  21: Train ELBO = 2357.059, Valid ELBO = 2361.122, Lie = 0.000, Patience = 0/5
#    Epoch  23: Train ELBO = 2345.573, Valid ELBO = 2345.321, Lie = 0.000, Patience = 0/5
#    Epoch  24: Train ELBO = 2336.754, Valid ELBO = 2341.079, Lie = 0.000, Patience = 0/5
#    Epoch  25: Train ELBO = 2330.956, Valid ELBO = 2332.203, Lie = 0.000, Patience = 0/5
#    ✅ Restored model with best validation ELBO: 2332.203369
# 📊 Comprehensive vector field analysis saved: vector_field_plots/perturb_0_5_lambda_0_00e00/vector_field_analysis_epoch_025_final.png
# 📊 Comprehensive comparison plot saved: vector_field_plots/perturb_0_5_lambda_0_00e00/comprehensive_comparison.png
# 🎯 All vector field plots saved to: vector_field_plots/perturb_0_5_lambda_0_00e00
#    Final: ELBO = 2336.166, Lie = 0.000, Total = 2336.166
#    📊 Diff from perfect_ring: mean=0.096, max=0.354
#    📊 Diff from perturbed_ring: mean=0.076, max=0.324
#    📊 Diff from target_rotation: mean=0.816, max=1.762
#
# --- Training 2/4: λ = 1.00e-04, perturbation = 0.5 ---
# 📁 Vector field plots will be saved to: vector_field_plots/perturb_0_5_lambda_1_00eneg04
# 🚀 Training with λ_lie = 1.00e-04
#    Max epochs: 25, Patience: 5
#    Early stopping on: validation ELBO loss
# 📊 Comprehensive vector field analysis saved: vector_field_plots/perturb_0_5_lambda_1_00eneg04/vector_field_analysis_epoch_-01_initial.png
#    Initial: Train ELBO = 32875.188, Valid ELBO = 33095.996, Lie = 9140015.000
#    Epoch   1: Train ELBO = 32111.900, Valid ELBO = 31453.150, Lie = 444176.938, Patience = 0/5
#    Epoch   2: Train ELBO = 30085.695, Valid ELBO = 26254.141, Lie = 187749.219, Patience = 0/5
#    Epoch   3: Train ELBO = 15520.655, Valid ELBO = 8781.517, Lie = 347138.062, Patience = 0/5
#    Epoch   4: Train ELBO = 6208.266, Valid ELBO = 5164.350, Lie = 70446.461, Patience = 0/5
#    Epoch   5: Train ELBO = 5079.241, Valid ELBO = 4910.863, Lie = 96809.961, Patience = 0/5
#    Epoch   6: Train ELBO = 4780.117, Valid ELBO = 4665.119, Lie = 90730.102, Patience = 0/5
#    Epoch   7: Train ELBO = 4431.737, Valid ELBO = 4359.488, Lie = 60693.598, Patience = 0/5
#    Epoch   8: Train ELBO = 3985.106, Valid ELBO = 3959.635, Lie = 32856.445, Patience = 0/5
#    Epoch   9: Train ELBO = 3493.625, Valid ELBO = 3374.721, Lie = 7136.987, Patience = 0/5
# 📊 Comprehensive vector field analysis saved: vector_field_plots/perturb_0_5_lambda_1_00eneg04/vector_field_analysis_epoch_010.png
#    Epoch  10: Train ELBO = 2970.304, Valid ELBO = 2729.969, Lie = 963.049, Patience = 0/5
#    Epoch  11: Train ELBO = 2616.319, Valid ELBO = 2576.986, Lie = 464.875, Patience = 0/5
#    Epoch  12: Train ELBO = 2518.879, Valid ELBO = 2511.574, Lie = 453.938, Patience = 0/5
#    Epoch  13: Train ELBO = 2467.997, Valid ELBO = 2456.412, Lie = 379.192, Patience = 0/5
#    Epoch  14: Train ELBO = 2439.387, Valid ELBO = 2431.644, Lie = 339.292, Patience = 0/5
#    Epoch  15: Train ELBO = 2414.203, Valid ELBO = 2410.436, Lie = 340.631, Patience = 0/5
#    Epoch  16: Train ELBO = 2391.445, Valid ELBO = 2398.043, Lie = 282.986, Patience = 0/5
#    Epoch  17: Train ELBO = 2382.790, Valid ELBO = 2372.633, Lie = 366.165, Patience = 0/5
#    Epoch  18: Train ELBO = 2373.597, Valid ELBO = 2368.214, Lie = 360.736, Patience = 0/5
#    Epoch  19: Train ELBO = 2363.188, Valid ELBO = 2358.322, Lie = 353.751, Patience = 0/5
# 📊 Comprehensive vector field analysis saved: vector_field_plots/perturb_0_5_lambda_1_00eneg04/vector_field_analysis_epoch_020.png
#    Epoch  20: Train ELBO = 2356.256, Valid ELBO = 2368.811, Lie = 290.576, Patience = 1/5
#    Epoch  21: Train ELBO = 2348.765, Valid ELBO = 2347.183, Lie = 309.550, Patience = 0/5
#    Epoch  22: Train ELBO = 2341.188, Valid ELBO = 2342.288, Lie = 309.727, Patience = 0/5
#    Epoch  23: Train ELBO = 2334.104, Valid ELBO = 2338.882, Lie = 273.159, Patience = 0/5
#    Epoch  24: Train ELBO = 2328.010, Valid ELBO = 2329.511, Lie = 287.096, Patience = 0/5
#    Epoch  25: Train ELBO = 2327.855, Valid ELBO = 2323.211, Lie = 304.550, Patience = 0/5
#    ✅ Restored model with best validation ELBO: 2323.211182
# 📊 Comprehensive vector field analysis saved: vector_field_plots/perturb_0_5_lambda_1_00eneg04/vector_field_analysis_epoch_025_final.png
# 📊 Comprehensive comparison plot saved: vector_field_plots/perturb_0_5_lambda_1_00eneg04/comprehensive_comparison.png
# 🎯 All vector field plots saved to: vector_field_plots/perturb_0_5_lambda_1_00eneg04
#    Final: ELBO = 2325.386, Lie = 304.243, Total = 2325.417
#    📊 Diff from perfect_ring: mean=0.097, max=0.355
#    📊 Diff from perturbed_ring: mean=0.076, max=0.320
#    📊 Diff from target_rotation: mean=0.816, max=1.746
#
# --- Training 3/4: λ = 1.00e-02, perturbation = 0.5 ---
# 📁 Vector field plots will be saved to: vector_field_plots/perturb_0_5_lambda_1_00eneg02
# 🚀 Training with λ_lie = 1.00e-02
#    Max epochs: 25, Patience: 5
#    Early stopping on: validation ELBO loss
# 📊 Comprehensive vector field analysis saved: vector_field_plots/perturb_0_5_lambda_1_00eneg02/vector_field_analysis_epoch_-01_initial.png
#    Initial: Train ELBO = 32875.480, Valid ELBO = 33093.793, Lie = 9135416.000
#    Epoch   1: Train ELBO = 32548.430, Valid ELBO = 31722.404, Lie = 190271.969, Patience = 0/5
#    Epoch   2: Train ELBO = 30198.631, Valid ELBO = 27097.670, Lie = 136767.922, Patience = 0/5
#    Epoch   3: Train ELBO = 18518.316, Valid ELBO = 12608.770, Lie = 236854.406, Patience = 0/5
#    Epoch   4: Train ELBO = 8442.209, Valid ELBO = 5995.193, Lie = 103985.641, Patience = 0/5
#    Epoch   5: Train ELBO = 5359.060, Valid ELBO = 5206.329, Lie = 55378.148, Patience = 0/5
#    Epoch   6: Train ELBO = 5006.080, Valid ELBO = 4935.816, Lie = 39397.137, Patience = 0/5
#    Epoch   7: Train ELBO = 4740.780, Valid ELBO = 4643.432, Lie = 34674.688, Patience = 0/5
#    Epoch   8: Train ELBO = 4444.293, Valid ELBO = 4361.311, Lie = 25548.666, Patience = 0/5
#    Epoch   9: Train ELBO = 4042.226, Valid ELBO = 3884.402, Lie = 12725.285, Patience = 0/5
# 📊 Comprehensive vector field analysis saved: vector_field_plots/perturb_0_5_lambda_1_00eneg02/vector_field_analysis_epoch_010.png
#    Epoch  10: Train ELBO = 3389.404, Valid ELBO = 3113.952, Lie = 2007.091, Patience = 0/5
#    Epoch  11: Train ELBO = 2747.302, Valid ELBO = 2625.878, Lie = 376.794, Patience = 0/5
#    Epoch  12: Train ELBO = 2523.335, Valid ELBO = 2514.246, Lie = 292.795, Patience = 0/5
#    Epoch  13: Train ELBO = 2462.766, Valid ELBO = 2454.957, Lie = 296.177, Patience = 0/5
#    Epoch  14: Train ELBO = 2430.182, Valid ELBO = 2434.614, Lie = 297.619, Patience = 0/5
#    Epoch  15: Train ELBO = 2410.483, Valid ELBO = 2417.898, Lie = 331.149, Patience = 0/5
#    Epoch  16: Train ELBO = 2393.030, Valid ELBO = 2408.298, Lie = 290.888, Patience = 0/5
#    Epoch  17: Train ELBO = 2382.504, Valid ELBO = 2389.456, Lie = 302.056, Patience = 0/5
#    Epoch  18: Train ELBO = 2367.241, Valid ELBO = 2376.254, Lie = 289.031, Patience = 0/5
#    Epoch  19: Train ELBO = 2356.059, Valid ELBO = 2361.594, Lie = 272.252, Patience = 0/5
# 📊 Comprehensive vector field analysis saved: vector_field_plots/perturb_0_5_lambda_1_00eneg02/vector_field_analysis_epoch_020.png
#    Epoch  20: Train ELBO = 2350.706, Valid ELBO = 2364.901, Lie = 267.482, Patience = 1/5
#    Epoch  21: Train ELBO = 2341.239, Valid ELBO = 2349.948, Lie = 288.674, Patience = 0/5
#    Epoch  22: Train ELBO = 2335.178, Valid ELBO = 2347.634, Lie = 270.199, Patience = 0/5
#    Epoch  23: Train ELBO = 2326.496, Valid ELBO = 2343.397, Lie = 234.660, Patience = 0/5
#    Epoch  24: Train ELBO = 2328.327, Valid ELBO = 2334.118, Lie = 296.987, Patience = 0/5
#    Epoch  25: Train ELBO = 2321.981, Valid ELBO = 2332.059, Lie = 282.953, Patience = 0/5
#    ✅ Restored model with best validation ELBO: 2332.058594
# 📊 Comprehensive vector field analysis saved: vector_field_plots/perturb_0_5_lambda_1_00eneg02/vector_field_analysis_epoch_025_final.png
# 📊 Comprehensive comparison plot saved: vector_field_plots/perturb_0_5_lambda_1_00eneg02/comprehensive_comparison.png
# 🎯 All vector field plots saved to: vector_field_plots/perturb_0_5_lambda_1_00eneg02
#    Final: ELBO = 2328.823, Lie = 282.581, Total = 2331.648
#    📊 Diff from perfect_ring: mean=0.100, max=0.359
#    📊 Diff from perturbed_ring: mean=0.079, max=0.330
#    📊 Diff from target_rotation: mean=0.814, max=1.769
#
# --- Training 4/4: λ = 1.00e+00, perturbation = 0.5 ---
# 📁 Vector field plots will be saved to: vector_field_plots/perturb_0_5_lambda_1_00e00
# 🚀 Training with λ_lie = 1.00e+00
#    Max epochs: 25, Patience: 5
#    Early stopping on: validation ELBO loss
# 📊 Comprehensive vector field analysis saved: vector_field_plots/perturb_0_5_lambda_1_00e00/vector_field_analysis_epoch_-01_initial.png
#    Initial: Train ELBO = 32875.609, Valid ELBO = 33094.980, Lie = 9147146.000
#    Epoch   1: Train ELBO = 33932.559, Valid ELBO = 35205.391, Lie = 24726.723, Patience = 0/5
#    Epoch   2: Train ELBO = 33689.262, Valid ELBO = 32166.311, Lie = 15199.872, Patience = 0/5
#    Epoch   3: Train ELBO = 27567.887, Valid ELBO = 23592.410, Lie = 37710.242, Patience = 0/5
#    Epoch   4: Train ELBO = 21613.285, Valid ELBO = 21439.238, Lie = 24859.133, Patience = 0/5
#    Epoch   5: Train ELBO = 19754.293, Valid ELBO = 19445.869, Lie = 27103.457, Patience = 0/5
#    Epoch   8: Train ELBO = 17090.029, Valid ELBO = 17485.471, Lie = 29595.066, Patience = 0/5
#    Epoch   9: Train ELBO = 14212.019, Valid ELBO = 13494.028, Lie = 40796.000, Patience = 0/5
# 📊 Comprehensive vector field analysis saved: vector_field_plots/perturb_0_5_lambda_1_00e00/vector_field_analysis_epoch_010.png
#    Epoch  10: Train ELBO = 12005.285, Valid ELBO = 12356.764, Lie = 28069.803, Patience = 0/5
#    Epoch  12: Train ELBO = 10338.233, Valid ELBO = 10569.450, Lie = 25885.289, Patience = 0/5
#    Epoch  13: Train ELBO = 8899.758, Valid ELBO = 8901.622, Lie = 21320.748, Patience = 0/5
#    Epoch  14: Train ELBO = 7895.234, Valid ELBO = 7854.169, Lie = 16325.115, Patience = 0/5
#    Epoch  15: Train ELBO = 6686.596, Valid ELBO = 6974.879, Lie = 9860.721, Patience = 0/5
#    Epoch  16: Train ELBO = 6624.702, Valid ELBO = 6462.959, Lie = 13899.523, Patience = 0/5
#    Epoch  17: Train ELBO = 5859.607, Valid ELBO = 6317.714, Lie = 5275.932, Patience = 0/5
#    Epoch  18: Train ELBO = 5037.317, Valid ELBO = 4881.458, Lie = 2475.012, Patience = 0/5
#    Epoch  19: Train ELBO = 4489.183, Valid ELBO = 4086.934, Lie = 980.838, Patience = 0/5
# 📊 Comprehensive vector field analysis saved: vector_field_plots/perturb_0_5_lambda_1_00e00/vector_field_analysis_epoch_020.png
#    Epoch  20: Train ELBO = 3884.840, Valid ELBO = 3622.745, Lie = 592.609, Patience = 0/5
#    Epoch  21: Train ELBO = 3431.667, Valid ELBO = 3295.455, Lie = 363.135, Patience = 0/5
#    Epoch  22: Train ELBO = 3165.835, Valid ELBO = 3144.673, Lie = 275.552, Patience = 0/5
#    Epoch  23: Train ELBO = 2995.097, Valid ELBO = 2954.444, Lie = 221.908, Patience = 0/5
#    Epoch  24: Train ELBO = 2832.357, Valid ELBO = 2819.032, Lie = 129.928, Patience = 0/5
#    Epoch  25: Train ELBO = 2733.162, Valid ELBO = 2690.211, Lie = 71.204, Patience = 0/5
#    ✅ Restored model with best validation ELBO: 2690.210938
# 📊 Comprehensive vector field analysis saved: vector_field_plots/perturb_0_5_lambda_1_00e00/vector_field_analysis_epoch_025_final.png
# 📊 Comprehensive comparison plot saved: vector_field_plots/perturb_0_5_lambda_1_00e00/comprehensive_comparison.png
# 🎯 All vector field plots saved to: vector_field_plots/perturb_0_5_lambda_1_00e00
#    Final: ELBO = 2704.695, Lie = 70.040, Total = 2774.735
#    📊 Diff from perfect_ring: mean=0.141, max=0.802
#    📊 Diff from perturbed_ring: mean=0.141, max=0.774
#    📊 Diff from target_rotation: mean=0.856, max=2.307
#
# ✅ Comprehensive sweep completed in 899.2 minutes
#    Trained 16 models successfully
#    📊 Vector field evolution + difference heatmaps saved for each experiment
#    📁 All comprehensive analyses organized in: vector_field_plots/
#
# 🎬 Each experiment includes analysis across perturbation magnitudes and regularization strengths
#    This allows studying how both data complexity and regularization affect learning

# %% [markdown]
# ## 📊 Comprehensive Analysis and Visualization

# %%
# Convert results to DataFrame for analysis with perturbation magnitude dimension
df_results = pd.DataFrame(all_results)

print(f"📊 Comprehensive Training Results Summary:")
print(f"   Total experiments: {len(df_results)}")
print(f"   Perturbation magnitudes: {sorted(df_results['perturbation_magnitude'].unique())}")
print(f"   Lambda values per perturbation: {len(df_results[df_results['perturbation_magnitude'] == cfg.perturbation_magnitudes[0]])}")
print(f"   Converged models: {df_results['converged'].sum()}/{len(df_results)}")
print(f"   Average final epoch: {df_results['final_epoch'].mean():.1f}")
print(f"   ELBO loss range: {df_results['final_elbo_loss'].min():.3f} - {df_results['final_elbo_loss'].max():.3f}")
print(f"   Lie loss range: {df_results['final_lie_loss'].min():.3e} - {df_results['final_lie_loss'].max():.3e}")

# Save results with perturbation magnitude information
df_results.to_csv('regularization_sweep_results_perturb_mag.csv', index=False)
print(f"💾 Results saved to regularization_sweep_results_perturb_mag.csv")
# Out:
# 📊 Comprehensive Training Results Summary:
#    Total experiments: 16
#    Perturbation magnitudes: [0.2, 0.3, 0.4, 0.5]
#    Lambda values per perturbation: 4
#    Converged models: 16/16
#    Average final epoch: 25.0
#    ELBO loss range: 2288.354 - 2704.695
#    Lie loss range: 0.000e+00 - 3.042e+02
# 💾 Results saved to regularization_sweep_results_perturb_mag.csv

# %%
df_results = pd.read_csv("regularization_sweep_results_perturb_mag.csv")

# Enhanced visualization for perturbation magnitude × regularization strength analysis
fig, axes = plt.subplots(3, 3, figsize=(24, 18))

# Create color map for perturbation magnitudes
colors = plt.cm.viridis(np.linspace(0, 1, len(cfg.perturbation_magnitudes)))
perturb_colors = {mag: colors[i] for i, mag in enumerate(cfg.perturbation_magnitudes)}

# 1. Total Loss vs Lambda for each perturbation magnitude
ax = axes[0, 0]
for perturbation_magnitude in cfg.perturbation_magnitudes:
    subset = df_results[df_results['perturbation_magnitude'] == perturbation_magnitude]
    ax.semilogx(subset['lambda_lie'], subset['final_total_loss'], 
               'o-', color=perturb_colors[perturbation_magnitude], 
               linewidth=2, markersize=4, label=f'Perturb {perturbation_magnitude}')
ax.set_xlabel('λ_lie')
ax.set_ylabel('Final Total Loss')
ax.set_title('Total Loss vs Regularization\n(by Perturbation Magnitude)', fontweight='bold')
ax.legend()
ax.grid(True, alpha=0.3)

# 2. ELBO Loss vs Lambda for each perturbation magnitude
ax = axes[0, 1]
for perturbation_magnitude in cfg.perturbation_magnitudes:
    subset = df_results[df_results['perturbation_magnitude'] == perturbation_magnitude]
    ax.semilogx(subset['lambda_lie'], subset['final_elbo_loss'], 
               'o-', color=perturb_colors[perturbation_magnitude], 
               linewidth=2, markersize=4, label=f'Perturb {perturbation_magnitude}')
ax.set_xlabel('λ_lie')
ax.set_ylabel('Final ELBO Loss')
ax.set_title('ELBO Loss vs Regularization\n(by Perturbation Magnitude)', fontweight='bold')
ax.legend()
ax.grid(True, alpha=0.3)

# 3. Lie Loss vs Lambda for each perturbation magnitude
ax = axes[0, 2]
for perturbation_magnitude in cfg.perturbation_magnitudes:
    subset = df_results[df_results['perturbation_magnitude'] == perturbation_magnitude]
    # Check if all positive before using loglog
    if (subset['final_lie_loss'] > 0).all():
        ax.loglog(subset['lambda_lie'], subset['final_lie_loss'], 
                 'o-', color=perturb_colors[perturbation_magnitude], 
                 linewidth=2, markersize=4, label=f'Perturb {perturbation_magnitude}')
    else:
        ax.semilogx(subset['lambda_lie'], subset['final_lie_loss'], 
                   'o-', color=perturb_colors[perturbation_magnitude], 
                   linewidth=2, markersize=4, label=f'Perturb {perturbation_magnitude}')
ax.set_xlabel('λ_lie')
ax.set_ylabel('Final Lie Loss')
ax.set_title('Lie Loss vs Regularization\n(by Perturbation Magnitude)', fontweight='bold')
ax.legend()
ax.grid(True, alpha=0.3)

# 4. Effect of perturbation magnitude on ELBO loss (at fixed lambda values)
ax = axes[1, 0]
for lambda_lie in lambda_values[::2]:  # Show every other lambda for clarity
    subset = df_results[df_results['lambda_lie'] == lambda_lie]
    ax.plot(subset['perturbation_magnitude'], subset['final_elbo_loss'], 
           'o-', linewidth=2, markersize=6, label=f'λ = {lambda_lie:.2e}')
ax.set_xlabel('Perturbation Magnitude')
ax.set_ylabel('Final ELBO Loss')
ax.set_title('ELBO Loss vs Perturbation Magnitude\n(by Regularization Strength)', fontweight='bold')
ax.legend()
ax.grid(True, alpha=0.3)

# 5. Effect of perturbation magnitude on Lie loss (at fixed lambda values)
ax = axes[1, 1]
for lambda_lie in lambda_values[::2]:  # Show every other lambda for clarity
    subset = df_results[df_results['lambda_lie'] == lambda_lie]
    ax.plot(subset['perturbation_magnitude'], subset['final_lie_loss'], 
           'o-', linewidth=2, markersize=6, label=f'λ = {lambda_lie:.2e}')
ax.set_xlabel('Perturbation Magnitude')
ax.set_ylabel('Final Lie Loss')
ax.set_title('Lie Loss vs Perturbation Magnitude\n(by Regularization Strength)', fontweight='bold')
ax.legend()
ax.grid(True, alpha=0.3)

# 6. 2D heatmap: ELBO loss as function of both perturbation and lambda
ax = axes[1, 2]
# Create pivot table for heatmap
heatmap_data = df_results.pivot(index='perturbation_magnitude', columns='lambda_lie', values='final_elbo_loss')
im = ax.imshow(heatmap_data.values, aspect='auto', cmap='viridis', interpolation='nearest')
ax.set_xticks(range(len(heatmap_data.columns)))
ax.set_xticklabels([f'{x:.1e}' for x in heatmap_data.columns], rotation=45)
ax.set_yticks(range(len(heatmap_data.index)))
ax.set_yticklabels(heatmap_data.index)
ax.set_xlabel('λ_lie')
ax.set_ylabel('Perturbation Magnitude')
ax.set_title('ELBO Loss Heatmap', fontweight='bold')
plt.colorbar(im, ax=ax, label='ELBO Loss')

# 7. Vector field difference analysis
if 'final_diff_perturbed_ring_mean' in df_results.columns:
    ax = axes[2, 0]
    for perturbation_magnitude in cfg.perturbation_magnitudes:
        subset = df_results[df_results['perturbation_magnitude'] == perturbation_magnitude]
        ax.semilogx(subset['lambda_lie'], subset['final_diff_perturbed_ring_mean'], 
                   'o-', color=perturb_colors[perturbation_magnitude], 
                   linewidth=2, markersize=4, label=f'Perturb {perturbation_magnitude}')
    ax.set_xlabel('λ_lie')
    ax.set_ylabel('Mean Diff from Data-Generating Field')
    ax.set_title('Learned vs Data-Generating Field\n(by Perturbation Magnitude)', fontweight='bold')
    ax.legend()
    ax.grid(True, alpha=0.3)

# 8. Target field difference analysis
if 'final_diff_target_rotation_mean' in df_results.columns:
    ax = axes[2, 1]
    for perturbation_magnitude in cfg.perturbation_magnitudes:
        subset = df_results[df_results['perturbation_magnitude'] == perturbation_magnitude]
        ax.semilogx(subset['lambda_lie'], subset['final_diff_target_rotation_mean'], 
                   'o-', color=perturb_colors[perturbation_magnitude], 
                   linewidth=2, markersize=4, label=f'Perturb {perturbation_magnitude}')
    ax.set_xlabel('λ_lie')
    ax.set_ylabel('Mean Diff from Target Rotation')
    ax.set_title('Learned vs Target Rotation Field\n(by Perturbation Magnitude)', fontweight='bold')
    ax.legend()
    ax.grid(True, alpha=0.3)

# 9. Training convergence analysis
# ax = axes[2, 2]
# for perturbation_magnitude in cfg.perturbation_magnitudes:
#     subset = df_results[df_results['perturbation_magnitude'] == perturbation_magnitude]
#     colors_convergence = ['green' if converged else 'red' for converged in subset['converged']]
#     scatter = ax.scatter(subset['lambda_lie'], subset['final_epoch'], 
#                         c=colors_convergence, alpha=0.7, s=50, 
#                         label=f'Perturb {perturbation_magnitude}')

# ax.set_xscale('log')
# ax.set_xlabel('λ_lie')
# ax.set_ylabel('Final Epoch')
# ax.set_title('Training Convergence\n(Green=Converged, Red=Max Epochs)', fontweight='bold')
# ax.grid(True, alpha=0.3)

# 9. Perfect ring difference analysis
if 'final_diff_perfect_ring_mean' in df_results.columns:
    ax = axes[2, 2]
    for perturbation_magnitude in cfg.perturbation_magnitudes:
        subset = df_results[df_results['perturbation_magnitude'] == perturbation_magnitude]
        ax.semilogx(subset['lambda_lie'], subset['final_diff_perfect_ring_mean'], 
                   'o-', color=perturb_colors[perturbation_magnitude], 
                   linewidth=2, markersize=4, label=f'Perturb {perturbation_magnitude}')
    ax.set_xlabel('λ_lie')
    ax.set_ylabel('Mean Diff from Perfect Ring')
    ax.set_title('Learned vs Perfect Ring Attractor\n(by Perturbation Magnitude)', fontweight='bold')
    ax.legend()
    ax.grid(True, alpha=0.3)

plt.tight_layout()
plt.savefig('comprehensive_perturbation_regularization_analysis.png', dpi=300, bbox_inches='tight')
plt.show()

print("📊 Comprehensive perturbation magnitude × regularization analysis generated")
print("   This reveals how data complexity (perturbation) interacts with regularization strength")
# Out:
# 📊 Comprehensive perturbation magnitude × regularization analysis generated
#    This reveals how data complexity (perturbation) interacts with regularization strength

# %% [markdown]
# ## 🎯 Optimal Regularization Analysis

# %%
# Find optimal regularization values using different criteria
def find_optimal_lambda_criteria(df):
    """Find optimal lambda using various criteria."""
    results = {}
    
    # 1. Minimum total loss
    min_total_idx = df['final_total_loss'].idxmin()
    results['min_total_loss'] = {
        'lambda_lie': df.loc[min_total_idx, 'lambda_lie'],
        'total_loss': df.loc[min_total_idx, 'final_total_loss'],
        'elbo_loss': df.loc[min_total_idx, 'final_elbo_loss'],
        'lie_loss': df.loc[min_total_idx, 'final_lie_loss']
    }
    
    # 2. Minimum ELBO loss (data fitting)
    min_elbo_idx = df['final_elbo_loss'].idxmin()
    results['min_elbo_loss'] = {
        'lambda_lie': df.loc[min_elbo_idx, 'lambda_lie'],
        'total_loss': df.loc[min_elbo_idx, 'final_total_loss'],
        'elbo_loss': df.loc[min_elbo_idx, 'final_elbo_loss'],
        'lie_loss': df.loc[min_elbo_idx, 'final_lie_loss']
    }
    
    # 3. Best lie loss while keeping ELBO reasonable (< 2x minimum)
    min_elbo = df['final_elbo_loss'].min()
    reasonable_elbo_mask = df['final_elbo_loss'] <= 2 * min_elbo
    if reasonable_elbo_mask.any():
        reasonable_df = df[reasonable_elbo_mask]
        best_lie_idx = reasonable_df['final_lie_loss'].idxmin()
        results['best_lie_reasonable_elbo'] = {
            'lambda_lie': df.loc[best_lie_idx, 'lambda_lie'],
            'total_loss': df.loc[best_lie_idx, 'final_total_loss'],
            'elbo_loss': df.loc[best_lie_idx, 'final_elbo_loss'],
            'lie_loss': df.loc[best_lie_idx, 'final_lie_loss']
        }
    
    # 4. Balanced approach: minimize normalized sum
    elbo_normalized = (df['final_elbo_loss'] - df['final_elbo_loss'].min()) / df['final_elbo_loss'].std()
    lie_normalized = (df['final_lie_loss'] - df['final_lie_loss'].min()) / df['final_lie_loss'].std()
    balanced_score = elbo_normalized + lie_normalized
    balanced_idx = balanced_score.idxmin()
    results['balanced'] = {
        'lambda_lie': df.loc[balanced_idx, 'lambda_lie'],
        'total_loss': df.loc[balanced_idx, 'final_total_loss'],
        'elbo_loss': df.loc[balanced_idx, 'final_elbo_loss'],
        'lie_loss': df.loc[balanced_idx, 'final_lie_loss']
    }
    
    return results

# Find optimal values
optimal_results = find_optimal_lambda_criteria(df_results)

print("🎯 Optimal Regularization Analysis:")
print("\n" + "="*80)
for criterion, result in optimal_results.items():
    print(f"\n{criterion.upper().replace('_', ' ')}:")
    print(f"   λ_lie = {result['lambda_lie']:.2e}")
    print(f"   Total Loss = {result['total_loss']:.6f}")
    print(f"   ELBO Loss = {result['elbo_loss']:.6f}")
    print(f"   Lie Loss = {result['lie_loss']:.6f}")
    
# Recommend the balanced approach
recommended = optimal_results['balanced']
print(f"\n🏆 RECOMMENDATION (Balanced Approach):")
print(f"   Use λ_lie = {recommended['lambda_lie']:.2e}")
print(f"   This provides good balance between data fitting and symmetry")
# Out:
# 🎯 Optimal Regularization Analysis:
#
# ================================================================================
#
# MIN TOTAL LOSS:
#    λ_lie = 1.00e-04
#    Total Loss = 2288.365234
#    ELBO Loss = 2288.354004
#    Lie Loss = 112.732307
#
# MIN ELBO LOSS:
#    λ_lie = 1.00e-04
#    Total Loss = 2288.365234
#    ELBO Loss = 2288.354004
#    Lie Loss = 112.732307
#
# BEST LIE REASONABLE ELBO:
#    λ_lie = 0.00e+00
#    Total Loss = 2318.312012
#    ELBO Loss = 2318.312012
#    Lie Loss = 0.000000
#
# BALANCED:
#    λ_lie = 0.00e+00
#    Total Loss = 2289.105713
#    ELBO Loss = 2289.105713
#    Lie Loss = 0.000000
#
# 🏆 RECOMMENDATION (Balanced Approach):
#    Use λ_lie = 0.00e+00
#    This provides good balance between data fitting and symmetry

# %% [markdown]
# ## 📈 Detailed Training Curves for Key Models

# %%
# Show detailed training curves for interesting lambda values
interesting_lambdas = [
    optimal_results['min_elbo_loss']['lambda_lie'],
    optimal_results['balanced']['lambda_lie'],
    optimal_results['min_total_loss']['lambda_lie']
]

if 'best_lie_reasonable_elbo' in optimal_results:
    interesting_lambdas.append(optimal_results['best_lie_reasonable_elbo']['lambda_lie'])

# Remove duplicates and sort
interesting_lambdas = sorted(list(set(interesting_lambdas)))

print(f"📈 Showing detailed training curves for {len(interesting_lambdas)} key models:")
for lambda_val in interesting_lambdas:
    print(f"   λ = {lambda_val:.2e}")

# Create subplot for each interesting lambda
n_models = len(interesting_lambdas)
fig, axes = plt.subplots(n_models, 1, figsize=(15, 5*n_models))
if n_models == 1:
    axes = [axes]

for i, lambda_val in enumerate(interesting_lambdas):
    logger = all_loggers[lambda_val]
    df_train = logger.get_dataframe()
    
    ax = axes[i]
    
    # Plot key loss components
    ax.semilogy(df_train['epoch'], df_train['train_total_loss'], 'k-', label='Train Total', linewidth=2)
    ax.semilogy(df_train['epoch'], df_train['valid_total_loss'], 'k--', label='Valid Total', linewidth=2)
    ax.semilogy(df_train['epoch'], df_train['train_elbo_loss'], 'b-', label='Train ELBO', linewidth=2)
    ax.semilogy(df_train['epoch'], df_train['valid_elbo_loss'], 'b--', label='Valid ELBO', linewidth=2)
    ax.semilogy(df_train['epoch'], df_train['train_lie_loss'], 'r-', label='Train Lie', linewidth=2)
    ax.semilogy(df_train['epoch'], df_train['valid_lie_loss'], 'r--', label='Valid Lie', linewidth=2)
    
    ax.set_title(f'Training Curves: λ_lie = {lambda_val:.2e}', fontweight='bold', fontsize=14)
    ax.set_xlabel('Epoch')
    ax.set_ylabel('Loss')
    ax.legend()
    ax.grid(True, alpha=0.3)

plt.tight_layout()
plt.savefig('detailed_training_curves_v2.png', dpi=300, bbox_inches='tight')
plt.show()

print("📈 Detailed training curves saved")
# Out:
# 📈 Showing detailed training curves for 2 key models:
#    λ = 0.00e+00
#    λ = 1.00e-04
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[13], line 25
#      22     axes = [axes]
#      24 for i, lambda_val in enumerate(interesting_lambdas):
# ---> 25     logger = all_loggers[lambda_val]
#      26     df_train = logger.get_dataframe()
#      28     ax = axes[i]
#
# KeyError: 0.0

# %% [markdown]
# ## 🔍 Spatial Analysis of Best Model

# %%
# Select interesting lambda values for vector field visualization
n_plots = 6  # Number of subplots to show
interesting_lambda_indices = np.linspace(0, len(lambda_values)-1, n_plots, dtype=int)
interesting_lambdas = [lambda_values[i] for i in interesting_lambda_indices]

print(f"🌟 Visualizing vector field evolution for {n_plots} regularization strengths:")
for i, lambda_val in enumerate(interesting_lambdas):
    print(f"   {i+1}. λ = {lambda_val:.2e}")

# Create a large subplot grid to show vector field evolution
fig, axes = plt.subplots(2, 3, figsize=(18, 12))
axes = axes.flatten()

# Generate a grid for vector field plotting
x_range = np.linspace(-2, 2, 20)
y_range = np.linspace(-2, 2, 20)
X, Y = np.meshgrid(x_range, y_range)
grid_points = torch.tensor(np.stack([X.flatten(), Y.flatten()], axis=1), dtype=torch.float32)

for i, lambda_val in enumerate(interesting_lambdas):
    ax = axes[i]
    
    # Load the corresponding trained model
    ssm = create_regularized_ssm(lambda_lie=lambda_val)
    ssm.load_state_dict(trained_models[lambda_val])
    ssm.eval()
    
    # Plot learned vector field
    plot_utils.plot_two_d_vector_field(
        ssm.dynamics_mod.mean_fn, ax, min_xy=-2, max_xy=2
    )
    
    # Add some sample trajectories
    with torch.no_grad():        # Generate short trajectories from random initial conditions
        n_traj = 8
        z_0 = torch.zeros((1, n_traj, 2))
        z_0[0] = 1.5 * torch.randn(n_traj, 2)  # Random initial conditions
        z_pred = ssm.predict_forward(z_0, 15).detach()
        
        for j in range(n_traj):
            ax.plot(z_pred[0, j, :, 0], z_pred[0, j, :, 1], 
                   'k-', alpha=0.6, linewidth=1.5)
    
    # Styling
    ax.set_xlim(-2, 2)
    ax.set_ylim(-2, 2)
    ax.set_aspect('equal')
    ax.set_title(f'λ = {lambda_val:.2e}', fontweight='bold', fontsize=14)
    ax.grid(True, alpha=0.3)
    ax.set_xlabel('x₁')
    ax.set_ylabel('x₂')

plt.suptitle('Learned Vector Field Evolution with Regularization Strength', 
             fontsize=16, fontweight='bold', y=0.98)
plt.tight_layout()
plt.savefig('vector_field_evolution_v2.png', dpi=300, bbox_inches='tight')
plt.show()

print(f"🌟 Vector field evolution plot saved as 'vector_field_evolution_v2.png'")
print(f"    Shows smooth transition from unregularized to heavily regularized dynamics")
# Out:
# 🌟 Visualizing vector field evolution for 6 regularization strengths:
#    1. λ = 0.00e+00
#    2. λ = 1.00e-04
#    3. λ = 1.00e-02
#    4. λ = 1.00e+00
#    5. λ = 1.00e+02
#    6. λ = 1.00e+04
# 🌟 Vector field evolution plot saved as 'vector_field_evolution_v2.png'
#     Shows smooth transition from unregularized to heavily regularized dynamics

# %%
# Comparison with target vector field
fig, axes = plt.subplots(1, 4, figsize=(20, 5))

# Show target field and three key learned fields
comparison_lambdas = [
    lambda_values[0],      # Minimum regularization
    optimal_results['balanced']['lambda_lie'],  # Optimal
    lambda_values[-1]      # Maximum regularization
]

# Target vector field
ax = axes[0]
dt = 1e-2
plot_utils.plot_two_d_vector_field(
    lambda x: x + dt * target_field(x), ax, min_xy=-2, max_xy=2
)
plot_utils.plot_two_d_vector_field(
    target_field, ax, min_xy=-2, max_xy=2
)
ax.set_title('Target Vector Field\n(Perfect Rotation)', fontweight='bold', fontsize=12)
ax.set_xlim(-2, 2)
ax.set_ylim(-2, 2)
ax.set_aspect('equal')
ax.grid(True, alpha=0.3)
ax.set_xlabel('x₁')
ax.set_ylabel('x₂')

# Learned vector fields
titles = ['Minimal Reg.', 'Optimal Reg.', 'Maximal Reg.']
for i, (lambda_val, title) in enumerate(zip(comparison_lambdas, titles)):
    ax = axes[i+1]
    
    # Load model and plot
    ssm = create_regularized_ssm(lambda_lie=lambda_val)
    ssm.load_state_dict(trained_models[lambda_val])
    ssm.eval()
    
    plot_utils.plot_two_d_vector_field(
        ssm.dynamics_mod.mean_fn, ax, min_xy=-2, max_xy=2
    )
    
    ax.set_title(f'{title}\\nλ = {lambda_val:.2e}', fontweight='bold', fontsize=12)
    ax.set_xlim(-2, 2)
    ax.set_ylim(-2, 2)
    ax.set_aspect('equal')
    ax.grid(True, alpha=0.3)
    ax.set_xlabel('x₁')
    ax.set_ylabel('x₂')

plt.suptitle('Target vs Learned Vector Fields at Key Regularization Strengths', 
             fontsize=16, fontweight='bold', y=1.02)
plt.tight_layout()
plt.savefig('target_vs_learned_comparison_v2.png', dpi=300, bbox_inches='tight')
plt.show()

print(f"🎯 Target vs learned comparison saved as 'target_vs_learned_comparison_v2.png'")
print(f"    Shows progression from unconstrained to target-like dynamics")
# Out:
# 🎯 Target vs learned comparison saved as 'target_vs_learned_comparison_v2.png'
#     Shows progression from unconstrained to target-like dynamics

# %% [markdown]
# ## 🌟 Vector Field Evolution Analysis
#
# Let's visualize how the learned vector field smoothly changes as a function of regularization strength.

# %%
# Analyze the spatial distribution of symmetry violations for the best model
best_lambda = optimal_results['balanced']['lambda_lie']

print(f"🔍 Spatial analysis for best model (λ = {best_lambda:.2e})")

# Recreate the best model
best_ssm = create_regularized_ssm(lambda_lie=best_lambda)
best_ssm.load_state_dict(trained_models[best_lambda])
best_ssm.eval()

# Create analyzer and perform spatial analysis
analyzer = LossComponentAnalyzer(best_ssm, device=device)
spatial_data = analyzer.analyze_lie_derivative_spatial(grid_size=50, domain=(-2, 2))

# Plot spatial analysis
fig = analyzer.plot_spatial_analysis(spatial_data, save_path='spatial_analysis_best_model_v2.png')
plt.show()

print(f"🎯 Spatial Analysis Results:")
print(f"   Max Lie violation: {spatial_data['lie_loss'].max():.6f}")
print(f"   Mean Lie violation: {spatial_data['lie_loss'].mean():.6f}")
print(f"   Min Lie violation: {spatial_data['lie_loss'].min():.6f}")
print(f"   Std Lie violation: {spatial_data['lie_loss'].std():.6f}")
# Out:
# 🔍 Spatial analysis for best model (λ = 1.00e-04)
# 🎯 Spatial Analysis Results:
#    Max Lie violation: 0.070870
#    Mean Lie violation: 0.003791
#    Min Lie violation: 0.000000
#    Std Lie violation: 0.006419

# %% [markdown]
# ## 📋 Summary and Recommendations

# %%
# Create comprehensive summary
print("📋 COMPREHENSIVE ANALYSIS SUMMARY")
print("="*60)

print(f"\n🔬 EXPERIMENTAL SETUP:")
print(f"   Seed: {cfg.seed} (for reproducibility)")
print(f"   Data: {cfg.n_trials} trials, {cfg.n_time_bins} time bins, {cfg.n_neurons} neurons")
print(f"   Train/Valid split: {cfg.train_split:.1%}/{1-cfg.train_split:.1%}")
print(f"   Lambda range: {cfg.lambda_min:.1e} to {cfg.lambda_max} ({cfg.n_lambda_points} points)")

print(f"\n🚀 TRAINING RESULTS:")
print(f"   Converged models: {df_results['converged'].sum()}/{len(df_results)}")
print(f"   Average epochs: {df_results['final_epoch'].mean():.1f}")
print(f"   Total training time: {elapsed_time/60:.1f} minutes")

print(f"\n📊 LOSS RANGES:")
print(f"   ELBO Loss: {df_results['final_elbo_loss'].min():.3f} - {df_results['final_elbo_loss'].max():.3f}")
print(f"   Lie Loss: {df_results['final_lie_loss'].min():.2e} - {df_results['final_lie_loss'].max():.2e}")
print(f"   Total Loss: {df_results['final_total_loss'].min():.3f} - {df_results['final_total_loss'].max():.3f}")

print(f"\n🎯 OPTIMAL REGULARIZATION:")
recommended = optimal_results['balanced']
print(f"   Recommended λ_lie: {recommended['lambda_lie']:.2e}")
print(f"   Achieved ELBO loss: {recommended['elbo_loss']:.6f}")
print(f"   Achieved Lie loss: {recommended['lie_loss']:.6f}")
print(f"   Total loss: {recommended['total_loss']:.6f}")

print(f"\n🔍 KEY FINDINGS:")
print(f"   1. Early stopping on validation ELBO prevents overfitting")
print(f"   2. Gradual lambda sweep reveals smooth trade-off curves")
print(f"   3. Optimal regularization balances data fitting and symmetry")
print(f"   4. Comprehensive logging enables detailed analysis")
print(f"   5. Seeded runs ensure reproducible results")

print(f"\n💾 OUTPUT FILES:")
print(f"   - regularization_sweep_results_v2.csv")
print(f"   - comprehensive_regularization_analysis_v2.png")
print(f"   - detailed_training_curves_v2.png")
print(f"   - spatial_analysis_best_model_v2.png")

print(f"\n✅ Analysis complete! Use the recommended λ_lie value for optimal results.")
# Out:
# 📋 COMPREHENSIVE ANALYSIS SUMMARY
# ============================================================
#
# 🔬 EXPERIMENTAL SETUP:
#    Seed: 41 (for reproducibility)
#    Data: 1000 trials, 75 time bins, 100 neurons
#    Train/Valid split: 80.0%/20.0%
#    Lambda range: 1.0e-05 to 10000.0 (10 points)
#
# 🚀 TRAINING RESULTS:
#    Converged models: 10/11
#    Average epochs: 25.0
#    Total training time: 358.3 minutes
#
# 📊 LOSS RANGES:
#    ELBO Loss: 2378.917 - 40947.293
#    Lie Loss: 0.00e+00 - 1.87e+05
#    Total Loss: 2378.918 - 2366600.250
#
# 🎯 OPTIMAL REGULARIZATION:
#    Recommended λ_lie: 1.00e-04
#    Achieved ELBO loss: 2378.916748
#    Achieved Lie loss: 9.445191
#    Total loss: 2378.917725
#
# 🔍 KEY FINDINGS:
#    1. Early stopping on validation ELBO prevents overfitting
#    2. Gradual lambda sweep reveals smooth trade-off curves
#    3. Optimal regularization balances data fitting and symmetry
#    4. Comprehensive logging enables detailed analysis
#    5. Seeded runs ensure reproducible results
#
# 💾 OUTPUT FILES:
#    - regularization_sweep_results_v2.csv
#    - comprehensive_regularization_analysis_v2.png
#    - detailed_training_curves_v2.png
#    - spatial_analysis_best_model_v2.png
#
# ✅ Analysis complete! Use the recommended λ_lie value for optimal results.
